# %% [markdown]
# # Risk Models Using Tree-based Models
#
# Welcome to the second assignment of Course 2!

# %% [markdown]
# ## Outline
#
# - [1. Import Packages](#1)
# - [2. Load the Dataset](#2)
# - [3. Explore the Dataset](#3)
# - [4. Dealing with Missing Data](#4)
#     - [Exercise 1](#Ex-1)
# - [5. Decision Trees](#5)
#     - [Exercise 2](#Ex-2)
# - [6. Random Forests](#6)
#     - [Exercise 3](#Ex-3)
# - [7. Imputation](#7)
# - [8. Error Analysis](#8)
#     - [Exercise 4](#Ex-4)
# - [9. Imputation Approaches](#Ex-9)
#     - [Exercise 5](#Ex-5)
#     - [Exercise 6](#Ex-6)
# - [10. Comparison](#10)
# - [11. Explanations: SHAP](#)

# %% [markdown]
# In this assignment, you'll gain experience with tree based models by predicting the 10-year risk of death of individuals from the NHANES I epidemiology dataset (for a detailed description of this dataset you can check the [CDC Website](https://wwwn.cdc.gov/nchs/nhanes/nhefs/default.aspx/)). This is a challenging task and a great test bed for the machine learning methods we learned this week.
#
# As you go through the assignment, you'll learn about:
#
# - Dealing with Missing Data
#   - Complete Case Analysis.
#   - Imputation
# - Decision Trees
#   - Evaluation.
#   - Regularization.
# - Random Forests
#   - Hyperparameter Tuning.

# %% [markdown]
# <a name='1'></a>
# ## 1. Import Packages
#
# We'll first import all the common packages that we need for this assignment.
#
# - `shap` is a library that explains predictions made by machine learning models.
# - `sklearn` is one of the most popular machine learning libraries.
# - `itertools` allows us to conveniently manipulate iterable objects such as lists.
# - `pydotplus` is used together with `IPython.display.Image` to visualize graph structures such as decision trees.
# - `numpy` is a fundamental package for scientific computing in Python.
# - `pandas` is what we'll use to manipulate our data.
# - `seaborn` is a plotting library which has some convenient functions for visualizing missing data.
# - `matplotlib` is a plotting library.

# %%
import shap
import sklearn
import itertools
import pydotplus
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from IPython.display import Image 

from sklearn.tree import export_graphviz
from sklearn.externals.six import StringIO
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer, SimpleImputer

# We'll also import some helper functions that will be useful later on.
from util import load_data, cindex

# %% [markdown]
# <a name='2'></a>
# ## 2. Load the Dataset

# %% [markdown]
# Run the next cell to load in the NHANES I epidemiology dataset. This dataset contains various features of hospital patients as well as their outcomes, i.e. whether or not they died within 10 years.

# %%
X_dev, X_test, y_dev, y_test = load_data(10)

# %% [markdown]
# The dataset has been split into a development set (or dev set), which we will use to develop our risk models, and a test set, which we will use to test our models.
#
# We further split the dev set into a training and validation set, respectively to train and tune our models, using a 75/25 split (note that we set a random state to make this split repeatable).

# %%
X_train, X_val, y_train, y_val = train_test_split(X_dev, y_dev, test_size=0.25, random_state=10)

# %% [markdown]
# <a name='3'></a>
# ## 3. Explore the Dataset
#
# The first step is to familiarize yourself with the data. Run the next cell to get the size of your training set and look at a small sample.

# %%
print("X_train shape: {}".format(X_train.shape))
X_train.head()
# Out:
# X_train shape: (5147, 18)
#        Age  Diastolic BP  Poverty index  Race  Red blood cells  \
# 1599  43.0          84.0          637.0   1.0             49.3
# 2794  72.0          96.0          154.0   2.0             43.4
# 1182  54.0          78.0          205.0   1.0             43.8
# 6915  59.0          90.0          417.0   1.0             43.4
# 500   34.0          80.0          385.0   1.0             77.7
#
#       Sedimentation rate  Serum Albumin  Serum Cholesterol  Serum Iron  \
# 1599                10.0            5.0              253.0       134.0
# 2794                23.0            4.3              265.0       106.0
# 1182                12.0            4.2              206.0       180.0
# 6915                 9.0            4.5              327.0       114.0
# 500                  9.0            4.1              197.0        64.0
#
#       Serum Magnesium  Serum Protein  Sex  Systolic BP   TIBC    TS  \
# 1599             1.59            7.7  1.0          NaN  490.0  27.3
# 2794             1.66            6.8  2.0        208.0  301.0  35.2
# 1182             1.67            6.6  2.0          NaN  363.0  49.6
# 6915             1.65            7.6  2.0          NaN  347.0  32.9
# 500              1.74            7.3  2.0          NaN  376.0  17.0
#
#       White blood cells        BMI  Pulse pressure
# 1599                9.1  25.803007            34.0
# 2794                6.0  33.394319           112.0
# 1182                5.9  20.278410            34.0
# 6915                6.1  32.917744            78.0
# 500                 8.2  30.743489            30.0

# %% [markdown]
# Our targets `y` will be whether or not the target died within 10 years. Run the next cell to see the target data series.

# %%
y_train.head(20)
# Out:
# 1599    False
# 2794     True
# 1182    False
# 6915    False
# 500     False
# 1188     True
# 9739    False
# 3266    False
# 6681    False
# 8822    False
# 5856     True
# 3415    False
# 9366    False
# 7975    False
# 1397    False
# 6809    False
# 9461    False
# 9374    False
# 1170     True
# 158     False
# Name: time, dtype: bool

# %% [markdown]
# Use the next cell to examine individual cases and familiarize yourself with the features.

# %%
i = 10
print(X_train.iloc[i,:])
print("\nDied within 10 years? {}".format(y_train.loc[y_train.index[i]]))
# Out:
# Age                    67.000000
# Diastolic BP           94.000000
# Poverty index         114.000000
# Race                    1.000000
# Red blood cells        43.800000
# Sedimentation rate     12.000000
# Serum Albumin           3.700000
# Serum Cholesterol     178.000000
# Serum Iron             73.000000
# Serum Magnesium         1.850000
# Serum Protein           7.000000
# Sex                     1.000000
# Systolic BP           140.000000
# TIBC                  311.000000
# TS                     23.500000
# White blood cells       4.300000
# BMI                    17.481227
# Pulse pressure         46.000000
# Name: 5856, dtype: float64
#
# Died within 10 years? True

# %% [markdown]
# <a name='4'></a>
# ## 4. Dealing with Missing Data
#
# Looking at our data in `X_train`, we see that some of the data is missing: some values in the output of the previous cell are marked as `NaN` ("not a number").
#
# Missing data is a common occurrence in data analysis, that can be due to a variety of reasons, such as measuring instrument malfunction, respondents not willing or not able to supply information, and errors in the data collection process.
#
# Let's examine the missing data pattern. `seaborn` is an alternative to `matplotlib` that has some convenient plotting functions for data analysis. We can use its `heatmap` function to easily visualize the missing data pattern.
#
# Run the cell below to plot the missing data:

# %%
sns.heatmap(X_train.isnull(), cbar=False)
plt.title("Training")
plt.show()

sns.heatmap(X_val.isnull(), cbar=False)
plt.title("Validation")
plt.show()

# %% [markdown]
# For each feature, represented as a column, values that are present are shown in black, and missing values are set in a light color.
#
# From this plot, we can see that many values are missing for systolic blood pressure (`Systolic BP`).

# %% [markdown]
# <a name='Ex-1'></a>
# ### Exercise 1
#
# In the cell below, write a function to compute the fraction of cases with missing data. This will help us decide how we handle this missing data in the future.

# %% [markdown]
# <details>
# <summary>
#     <font size="3" color="darkgreen"><b>Hints</b></font>
# </summary>
# <p>
# <ul>
#     <li> The <code>pandas.DataFrame.isnull()</code> method is helpful in this case.</li>
#     <li> Use the <code>pandas.DataFrame.any()</code> method and set the <code>axis</code> parameter.</li>
#     <li> Divide the total number of rows with missing data by the total number of rows. Remember that in Python, <code>True</code> values are equal to 1.</li>
# </ul>
# </p>

# %%
# UNQ_C1 (UNIQUE CELL IDENTIFIER, DO NOT EDIT)
def fraction_rows_missing(df):
    '''
    Return percent of rows with any missing
    data in the dataframe. 
    
    Input:
        df (dataframe): a pandas dataframe with potentially missing data
    Output:
        frac_missing (float): fraction of rows with missing data
    '''
    ### START CODE HERE (REPLACE 'Pass' with your 'return' code) ###
    return sum(df.isnull().any(axis=1))/df.shape[0]
    ### END CODE HERE ###

# %% [markdown]
# Test your function by running the cell below.

# %%
df_test = pd.DataFrame({'a':[None, 1, 1, None], 'b':[1, None, 0, 1]})
print("Example dataframe:\n")
print(df_test)

print("\nComputed fraction missing: {}, expected: {}".format(fraction_rows_missing(df_test), 0.75))
print(f"Fraction of rows missing from X_train: {fraction_rows_missing(X_train):.3f}")
print(f"Fraction of rows missing from X_val: {fraction_rows_missing(X_val):.3f}")
print(f"Fraction of rows missing from X_test: {fraction_rows_missing(X_test):.3f}")
# Out:
# Example dataframe:
#
#      a    b
# 0  NaN  1.0
# 1  1.0  NaN
# 2  1.0  0.0
# 3  NaN  1.0
#
# Computed fraction missing: 0.75, expected: 0.75
# Fraction of rows missing from X_train: 0.699
# Fraction of rows missing from X_val: 0.704
# Fraction of rows missing from X_test: 0.000

# %% [markdown]
# We see that our train and validation sets have missing values, but luckily our test set has complete cases.

# %% [markdown]
# As a first pass, we will begin with a **complete case analysis**, dropping all of the rows with any missing data. Run the following cell to drop these rows from our train and validation sets.

# %%
X_train_dropped = X_train.dropna(axis='rows')
y_train_dropped = y_train.loc[X_train_dropped.index]
X_val_dropped = X_val.dropna(axis='rows')
y_val_dropped = y_val.loc[X_val_dropped.index]

# %% [markdown]
# <a name='5'></a>
# ## 5. Decision Trees
#
# Having just learned about decision trees, you choose to use a decision tree classifier. Use scikit-learn to build a decision tree for the hospital dataset using the train set.

# %%
dt = DecisionTreeClassifier(max_depth=None, random_state=10)
dt.fit(X_train_dropped, y_train_dropped)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=10, splitter='best')

# %% [markdown]
# Next we will evaluate our model. We'll use C-Index for evaluation.
#
# > Remember from lesson 4 of week 1 that the C-Index evaluates the ability of a model to differentiate between different classes, by quantifying how often, when considering all pairs of patients (A, B), the model says that patient A has a higher risk score than patient B when, in the observed data, patient A actually died and patient B actually lived. In our case, our model is a binary classifier, where each risk score is either 1 (the model predicts that the patient will die) or 0 (the patient will live).
# >
# > More formally, defining _permissible pairs_ of patients as pairs where the outcomes are different, _concordant pairs_ as permissible pairs where the patient that died had a higher risk score (i.e. our model predicted 1 for the patient that died and 0 for the one that lived), and _ties_ as permissible pairs where the risk scores were equal (i.e. our model predicted 1 for both patients or 0 for both patients), the C-Index is equal to:
# >
# > $$\text{C-Index} = \frac{\#\text{concordant pairs} + 0.5\times \#\text{ties}}{\#\text{permissible pairs}}$$
#
# Run the next cell to compute the C-Index on the train and validation set (we've given you an implementation this time).

# %%
y_train_preds = dt.predict_proba(X_train_dropped)[:, 1]
print(f"Train C-Index: {cindex(y_train_dropped.values, y_train_preds)}")


y_val_preds = dt.predict_proba(X_val_dropped)[:, 1]
print(f"Val C-Index: {cindex(y_val_dropped.values, y_val_preds)}")
# Out:
# Train C-Index: 1.0
# Val C-Index: 0.5629321808510638

# %% [markdown]
# Unfortunately your tree seems to be overfitting: it fits the training data so closely that it doesn't generalize well to other samples such as those from the validation set.
#
# > The training C-index comes out to 1.0 because, when initializing `DecisionTreeClasifier`, we have left `max_depth` and `min_samples_split` unspecified. The resulting decision tree will therefore keep splitting as far as it can, which pretty much guarantees a pure fit to the training data.
#
# To handle this, you can change some of the hyperparameters of our tree.

# %% [markdown]
# <a name='Ex-2'></a>
# ### Exercise 2
#
# Try and find a set of hyperparameters that improves the generalization to the validation set and recompute the C-index. If you do it right, you should get C-index above 0.6 for the validation set.
#
# You can refer to the documentation for the sklearn [DecisionTreeClassifier](https://scikit-learn.org/stable/modules/generated/sklearn.tree.DecisionTreeClassifier.html).

# %% [markdown]
# <details>
# <summary>
#     <font size="3" color="darkgreen"><b>Hints</b></font>
# </summary>
# <p>
# <ul>
#     <li> Try limiting the depth of the tree (<code>'max_depth'</code>).</li>
# </ul>
# </p>

# %%
# Experiment with different hyperparameters for the DecisionTreeClassifier
# until you get a c-index above 0.6 for the validation set
dt_hyperparams = {
    # set your own hyperparameters below, such as 'min_samples_split': 1

    ### START CODE HERE ###
    
    'max_depth':3,
    'min_samples_split':0.2,
    
    ### END CODE HERE ###
}

# %% [markdown]
# Run the next cell to fit and evaluate the regularized tree.

# %%
# UNQ_C2 (UNIQUE CELL IDENTIFIER, DO NOT EDIT)
dt_reg = DecisionTreeClassifier(**dt_hyperparams, random_state=10)
dt_reg.fit(X_train_dropped, y_train_dropped)

y_train_preds = dt_reg.predict_proba(X_train_dropped)[:, 1]
y_val_preds = dt_reg.predict_proba(X_val_dropped)[:, 1]
print(f"Train C-Index: {cindex(y_train_dropped.values, y_train_preds)}")
print(f"Val C-Index (expected > 0.6): {cindex(y_val_dropped.values, y_val_preds)}")
# Out:
# Train C-Index: 0.6780135398312158
# Val C-Index (expected > 0.6): 0.6247340425531915

# %% [markdown]
# If you used a low `max_depth` you can print the entire tree. This allows for easy interpretability. Run the next cell to print the tree splits.

# %%
dot_data = StringIO()
export_graphviz(dt_reg, feature_names=X_train_dropped.columns, out_file=dot_data,  
                filled=True, rounded=True, proportion=True, special_characters=True,
                impurity=False, class_names=['neg', 'pos'], precision=2)
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())  
Image(graph.create_png())

# %% [markdown]
# > **Overfitting, underfitting, and the bias-variance tradeoff**
# >
# > If you tested several values of `max_depth`, you may have seen that a value of `3` gives training and validation C-Indices of about `0.689` and `0.630`, and that a `max_depth` of `2` gives better agreement with values of about `0.653` and `0.607`. In the latter case, we have further reduced overfitting, at the cost of a minor loss in predictive performance.
# >
# > Contrast this with a `max_depth` value of `1`, which results in C-Indices of about `0.597` for the training set and `0.598` for the validation set: we have eliminated overfitting but with a much stronger degradation of predictive performance.
# >
# > Lower predictive performance on the training and validation sets is indicative of the model _underfitting_ the data: it neither learns enough from the training data nor is able to generalize to unseen data (the validation data in our case).
# >
# > Finding a model that minimizes and acceptably balances underfitting and overfitting (e.g. selecting the model with a `max_depth` of `2` over the other values) is a common problem in machine learning that is known as the _bias-variance tradeoff_.

# %% [markdown]
# <a name='6'></a>
# ## 6. Random Forests
#
# No matter how you choose hyperparameters, a single decision tree is prone to overfitting. To solve this problem, you can try **random forests**, which combine predictions from many different trees to create a robust classifier.
#
# As before, we will use scikit-learn to build a random forest for the data. We will use the default hyperparameters.

# %%
rf = RandomForestClassifier(n_estimators=100, random_state=10)
rf.fit(X_train_dropped, y_train_dropped)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=10, verbose=0,
#                        warm_start=False)

# %% [markdown]
# Now compute and report the C-Index for the random forest on the training and validation set.

# %%
y_train_rf_preds = rf.predict_proba(X_train_dropped)[:, 1]
print(f"Train C-Index: {cindex(y_train_dropped.values, y_train_rf_preds)}")

y_val_rf_preds = rf.predict_proba(X_val_dropped)[:, 1]
print(f"Val C-Index: {cindex(y_val_dropped.values, y_val_rf_preds)}")
# Out:
# Train C-Index: 1.0
# Val C-Index: 0.6660488696808511

# %% [markdown]
# Training a random forest with the default hyperparameters results in a model that has better predictive performance than individual decision trees as in the previous section, but this model is overfitting.
#
# We therefore need to tune (or optimize) the hyperparameters, to find a model that both has good predictive performance and minimizes overfitting.
#
# The hyperparameters we choose to adjust will be:
#
# - `n_estimators`: the number of trees used in the forest.
# - `max_depth`: the maximum depth of each tree.
# - `min_samples_leaf`: the minimum number (if `int`) or proportion (if `float`) of samples in a leaf.
#
# The approach we implement to tune the hyperparameters is known as a grid search:
#
# - We define a set of possible values for each of the target hyperparameters.
#
# - A model is trained and evaluated for every possible combination of hyperparameters.
#
# - The best performing set of hyperparameters is returned.
#
# The cell below implements a hyperparameter grid search, using the C-Index to evaluate each tested model.

# %%
def holdout_grid_search(clf, X_train_hp, y_train_hp, X_val_hp, y_val_hp, hyperparams, fixed_hyperparams={}):
    '''
    Conduct hyperparameter grid search on hold out validation set. Use holdout validation.
    Hyperparameters are input as a dictionary mapping each hyperparameter name to the
    range of values they should iterate over. Use the cindex function as your evaluation
    function.

    Input:
        clf: sklearn classifier
        X_train_hp (dataframe): dataframe for training set input variables
        y_train_hp (dataframe): dataframe for training set targets
        X_val_hp (dataframe): dataframe for validation set input variables
        y_val_hp (dataframe): dataframe for validation set targets
        hyperparams (dict): hyperparameter dictionary mapping hyperparameter
                            names to range of values for grid search
        fixed_hyperparams (dict): dictionary of fixed hyperparameters that
                                  are not included in the grid search

    Output:
        best_estimator (sklearn classifier): fitted sklearn classifier with best performance on
                                             validation set
        best_hyperparams (dict): hyperparameter dictionary mapping hyperparameter
                                 names to values in best_estimator
    '''
    best_estimator = None
    best_hyperparams = {}
    
    # hold best running score
    best_score = 0.0

    # get list of param values
    lists = hyperparams.values()
    
    # get all param combinations
    param_combinations = list(itertools.product(*lists))
    total_param_combinations = len(param_combinations)

    # iterate through param combinations
    for i, params in enumerate(param_combinations, 1):
        # fill param dict with params
        param_dict = {}
        for param_index, param_name in enumerate(hyperparams):
            param_dict[param_name] = params[param_index]
            
        # create estimator with specified params
        estimator = clf(**param_dict, **fixed_hyperparams)

        # fit estimator
        estimator.fit(X_train_hp, y_train_hp)
        
        # get predictions on validation set
        preds = estimator.predict_proba(X_val_hp)
        
        # compute cindex for predictions
        estimator_score = cindex(y_val_hp, preds[:,1])

        print(f'[{i}/{total_param_combinations}] {param_dict}')
        print(f'Val C-Index: {estimator_score}\n')

        # if new high score, update high score, best estimator
        # and best params 
        if estimator_score >= best_score:
                best_score = estimator_score
                best_estimator = estimator
                best_hyperparams = param_dict

    # add fixed hyperparamters to best combination of variable hyperparameters
    best_hyperparams.update(fixed_hyperparams)
    
    return best_estimator, best_hyperparams

# %% [markdown]
# <a name='Ex-3'></a>
# ### Exercise 3
#
# In the cell below, define the values you want to run the hyperparameter grid search on, and run the cell to find the best-performing set of hyperparameters.
#
# Your objective is to get a C-Index above `0.6` on both the train and validation set.

# %% [markdown]
# <details>
# <summary>
#     <font size="3" color="darkgreen"><b>Hints</b></font>
# </summary>
# <p>
# <ul>
#     <li>n_estimators: try values greater than 100</li>
#     <li>max_depth: try values in the range 1 to 100</li>
#     <li>min_samples_leaf: try float values below .5 and/or int values greater than 2</li>
# </ul>
# </p>

# %%
def random_forest_grid_search(X_train_dropped, y_train_dropped, X_val_dropped, y_val_dropped):

    # Define ranges for the chosen random forest hyperparameters 
    hyperparams = {
        
        ### START CODE HERE (REPLACE array values with your code) ###

        # how many trees should be in the forest (int)
        'n_estimators': range(50,100),

        # the maximum depth of trees in the forest (int)
        
        'max_depth': range(1,5),
        
        # the minimum number of samples in a leaf as a fraction
        # of the total number of samples in the training set
        # Can be int (in which case that is the minimum number)
        # or float (in which case the minimum is that fraction of the
        # number of training set samples)
        'min_samples_leaf': range(1,5),

        ### END CODE HERE ###
    }

    
    fixed_hyperparams = {
        'random_state': 10,
    }
    
    rf = RandomForestClassifier

    best_rf, best_hyperparams = holdout_grid_search(rf, X_train_dropped, y_train_dropped,
                                                    X_val_dropped, y_val_dropped, hyperparams,
                                                    fixed_hyperparams)

    print(f"Best hyperparameters:\n{best_hyperparams}")

    
    y_train_best = best_rf.predict_proba(X_train_dropped)[:, 1]
    print(f"Train C-Index: {cindex(y_train_dropped, y_train_best)}")

    y_val_best = best_rf.predict_proba(X_val_dropped)[:, 1]
    print(f"Val C-Index: {cindex(y_val_dropped, y_val_best)}")
    
    # add fixed hyperparamters to best combination of variable hyperparameters
    best_hyperparams.update(fixed_hyperparams)
    
    return best_rf, best_hyperparams

# %%
best_rf, best_hyperparams = random_forest_grid_search(X_train_dropped, y_train_dropped, X_val_dropped, y_val_dropped)
# Out:
# [1/800] {'n_estimators': 50, 'max_depth': 1, 'min_samples_leaf': 1}
# Val C-Index: 0.6576130319148936
#
# [2/800] {'n_estimators': 50, 'max_depth': 1, 'min_samples_leaf': 2}
# Val C-Index: 0.6576130319148936
#
# [3/800] {'n_estimators': 50, 'max_depth': 1, 'min_samples_leaf': 3}
# Val C-Index: 0.6576130319148936
#
# [4/800] {'n_estimators': 50, 'max_depth': 1, 'min_samples_leaf': 4}
# Val C-Index: 0.6576130319148936
#
# [5/800] {'n_estimators': 50, 'max_depth': 2, 'min_samples_leaf': 1}
# Val C-Index: 0.6595744680851063
#
# [6/800] {'n_estimators': 50, 'max_depth': 2, 'min_samples_leaf': 2}
# Val C-Index: 0.6595744680851063
#
# [7/800] {'n_estimators': 50, 'max_depth': 2, 'min_samples_leaf': 3}
# Val C-Index: 0.6598570478723405
#
# [8/800] {'n_estimators': 50, 'max_depth': 2, 'min_samples_leaf': 4}
# Val C-Index: 0.6602892287234042
#
# [9/800] {'n_estimators': 50, 'max_depth': 3, 'min_samples_leaf': 1}
# Val C-Index: 0.6724567819148937
#
# [10/800] {'n_estimators': 50, 'max_depth': 3, 'min_samples_leaf': 2}
# Val C-Index: 0.6722240691489362
#
# [11/800] {'n_estimators': 50, 'max_depth': 3, 'min_samples_leaf': 3}
# Val C-Index: 0.6725066489361702
#
# [12/800] {'n_estimators': 50, 'max_depth': 3, 'min_samples_leaf': 4}
# Val C-Index: 0.6725897606382979
#
# [13/800] {'n_estimators': 50, 'max_depth': 4, 'min_samples_leaf': 1}
# Val C-Index: 0.6665724734042553
#
# [14/800] {'n_estimators': 50, 'max_depth': 4, 'min_samples_leaf': 2}
# Val C-Index: 0.6681349734042553
#
# [15/800] {'n_estimators': 50, 'max_depth': 4, 'min_samples_leaf': 3}
# Val C-Index: 0.6666223404255319
#
# [16/800] {'n_estimators': 50, 'max_depth': 4, 'min_samples_leaf': 4}
# Val C-Index: 0.6624833776595744
#
# [17/800] {'n_estimators': 51, 'max_depth': 1, 'min_samples_leaf': 1}
# Val C-Index: 0.659375
#
# [18/800] {'n_estimators': 51, 'max_depth': 1, 'min_samples_leaf': 2}
# Val C-Index: 0.659375
#
# [19/800] {'n_estimators': 51, 'max_depth': 1, 'min_samples_leaf': 3}
# Val C-Index: 0.659375
#
# [20/800] {'n_estimators': 51, 'max_depth': 1, 'min_samples_leaf': 4}
# Val C-Index: 0.659375
#
# [21/800] {'n_estimators': 51, 'max_depth': 2, 'min_samples_leaf': 1}
# Val C-Index: 0.659873670212766
#
# [22/800] {'n_estimators': 51, 'max_depth': 2, 'min_samples_leaf': 2}
# Val C-Index: 0.659873670212766
#
# [23/800] {'n_estimators': 51, 'max_depth': 2, 'min_samples_leaf': 3}
# Val C-Index: 0.6603224734042553
#
# [24/800] {'n_estimators': 51, 'max_depth': 2, 'min_samples_leaf': 4}
# Val C-Index: 0.6606715425531915
#
# [25/800] {'n_estimators': 51, 'max_depth': 3, 'min_samples_leaf': 1}
# Val C-Index: 0.6728390957446808
#
# [26/800] {'n_estimators': 51, 'max_depth': 3, 'min_samples_leaf': 2}
# Val C-Index: 0.6725565159574468
#
# [27/800] {'n_estimators': 51, 'max_depth': 3, 'min_samples_leaf': 3}
# Val C-Index: 0.6730219414893617
#
# [28/800] {'n_estimators': 51, 'max_depth': 3, 'min_samples_leaf': 4}
# Val C-Index: 0.6732546542553192
#
# [29/800] {'n_estimators': 51, 'max_depth': 4, 'min_samples_leaf': 1}
# Val C-Index: 0.6679188829787234
#
# [30/800] {'n_estimators': 51, 'max_depth': 4, 'min_samples_leaf': 2}
# Val C-Index: 0.6689328457446808
#
# [31/800] {'n_estimators': 51, 'max_depth': 4, 'min_samples_leaf': 3}
# Val C-Index: 0.6681017287234042
#
# [32/800] {'n_estimators': 51, 'max_depth': 4, 'min_samples_leaf': 4}
# Val C-Index: 0.6636469414893617
#
# [33/800] {'n_estimators': 52, 'max_depth': 1, 'min_samples_leaf': 1}
# Val C-Index: 0.6609208776595744
#
# [34/800] {'n_estimators': 52, 'max_depth': 1, 'min_samples_leaf': 2}
# Val C-Index: 0.6609208776595744
#
# [35/800] {'n_estimators': 52, 'max_depth': 1, 'min_samples_leaf': 3}
# Val C-Index: 0.6609208776595744
#
# [36/800] {'n_estimators': 52, 'max_depth': 1, 'min_samples_leaf': 4}
# Val C-Index: 0.6609208776595744
#
# [37/800] {'n_estimators': 52, 'max_depth': 2, 'min_samples_leaf': 1}
# Val C-Index: 0.6603557180851064
#
# [38/800] {'n_estimators': 52, 'max_depth': 2, 'min_samples_leaf': 2}
# Val C-Index: 0.6603557180851064
#
# [39/800] {'n_estimators': 52, 'max_depth': 2, 'min_samples_leaf': 3}
# Val C-Index: 0.6606715425531915
#
# [40/800] {'n_estimators': 52, 'max_depth': 2, 'min_samples_leaf': 4}
# Val C-Index: 0.6608710106382979
#
# [41/800] {'n_estimators': 52, 'max_depth': 3, 'min_samples_leaf': 1}
# Val C-Index: 0.6730884308510638
#
# [42/800] {'n_estimators': 52, 'max_depth': 3, 'min_samples_leaf': 2}
# Val C-Index: 0.6728224734042553
#
# [43/800] {'n_estimators': 52, 'max_depth': 3, 'min_samples_leaf': 3}
# Val C-Index: 0.6730385638297872
#
# [44/800] {'n_estimators': 52, 'max_depth': 3, 'min_samples_leaf': 4}
# Val C-Index: 0.6738031914893617
#
# [45/800] {'n_estimators': 52, 'max_depth': 4, 'min_samples_leaf': 1}
# Val C-Index: 0.6677360372340425
#
# [46/800] {'n_estimators': 52, 'max_depth': 4, 'min_samples_leaf': 2}
# Val C-Index: 0.6690990691489361
#
# [47/800] {'n_estimators': 52, 'max_depth': 4, 'min_samples_leaf': 3}
# Val C-Index: 0.6668384308510639
#
# [48/800] {'n_estimators': 52, 'max_depth': 4, 'min_samples_leaf': 4}
# Val C-Index: 0.6624833776595744
#
# [49/800] {'n_estimators': 53, 'max_depth': 1, 'min_samples_leaf': 1}
# Val C-Index: 0.6605718085106383
#
# [50/800] {'n_estimators': 53, 'max_depth': 1, 'min_samples_leaf': 2}
# Val C-Index: 0.6605718085106383
#
# [51/800] {'n_estimators': 53, 'max_depth': 1, 'min_samples_leaf': 3}
# Val C-Index: 0.6605718085106383
#
# [52/800] {'n_estimators': 53, 'max_depth': 1, 'min_samples_leaf': 4}
# Val C-Index: 0.6605718085106383
#
# [53/800] {'n_estimators': 53, 'max_depth': 2, 'min_samples_leaf': 1}
# Val C-Index: 0.6602892287234042
#
# [54/800] {'n_estimators': 53, 'max_depth': 2, 'min_samples_leaf': 2}
# Val C-Index: 0.6602892287234042
#
# [55/800] {'n_estimators': 53, 'max_depth': 2, 'min_samples_leaf': 3}
# Val C-Index: 0.6608045212765957
#
# [56/800] {'n_estimators': 53, 'max_depth': 2, 'min_samples_leaf': 4}
# Val C-Index: 0.6610206117021277
#
# [57/800] {'n_estimators': 53, 'max_depth': 3, 'min_samples_leaf': 1}
# Val C-Index: 0.6727559840425532
#
# [58/800] {'n_estimators': 53, 'max_depth': 3, 'min_samples_leaf': 2}
# Val C-Index: 0.6724734042553191
#
# [59/800] {'n_estimators': 53, 'max_depth': 3, 'min_samples_leaf': 3}
# Val C-Index: 0.6730884308510638
#
# [60/800] {'n_estimators': 53, 'max_depth': 3, 'min_samples_leaf': 4}
# Val C-Index: 0.6735871010638298
#
# [61/800] {'n_estimators': 53, 'max_depth': 4, 'min_samples_leaf': 1}
# Val C-Index: 0.6683344414893617
#
# [62/800] {'n_estimators': 53, 'max_depth': 4, 'min_samples_leaf': 2}
# Val C-Index: 0.6702460106382979
#
# [63/800] {'n_estimators': 53, 'max_depth': 4, 'min_samples_leaf': 3}
# Val C-Index: 0.667719414893617
#
# [64/800] {'n_estimators': 53, 'max_depth': 4, 'min_samples_leaf': 4}
# Val C-Index: 0.6632646276595745
#
# [65/800] {'n_estimators': 54, 'max_depth': 1, 'min_samples_leaf': 1}
# Val C-Index: 0.6616023936170212
#
# [66/800] {'n_estimators': 54, 'max_depth': 1, 'min_samples_leaf': 2}
# Val C-Index: 0.6616023936170212
#
# [67/800] {'n_estimators': 54, 'max_depth': 1, 'min_samples_leaf': 3}
# Val C-Index: 0.6616023936170212
#
# [68/800] {'n_estimators': 54, 'max_depth': 1, 'min_samples_leaf': 4}
# Val C-Index: 0.6616023936170212
#
# [69/800] {'n_estimators': 54, 'max_depth': 2, 'min_samples_leaf': 1}
# Val C-Index: 0.659624335106383
#
# [70/800] {'n_estimators': 54, 'max_depth': 2, 'min_samples_leaf': 2}
# Val C-Index: 0.659624335106383
#
# [71/800] {'n_estimators': 54, 'max_depth': 2, 'min_samples_leaf': 3}
# Val C-Index: 0.6602393617021277
#
# [72/800] {'n_estimators': 54, 'max_depth': 2, 'min_samples_leaf': 4}
# Val C-Index: 0.6605551861702128
#
# [73/800] {'n_estimators': 54, 'max_depth': 3, 'min_samples_leaf': 1}
# Val C-Index: 0.6719248670212766
#
# [74/800] {'n_estimators': 54, 'max_depth': 3, 'min_samples_leaf': 2}
# Val C-Index: 0.6715093085106383
#
# [75/800] {'n_estimators': 54, 'max_depth': 3, 'min_samples_leaf': 3}
# Val C-Index: 0.6717253989361702
#
# [76/800] {'n_estimators': 54, 'max_depth': 3, 'min_samples_leaf': 4}
# Val C-Index: 0.6718583776595745
#
# [77/800] {'n_estimators': 54, 'max_depth': 4, 'min_samples_leaf': 1}
# Val C-Index: 0.669281914893617
#
# [78/800] {'n_estimators': 54, 'max_depth': 4, 'min_samples_leaf': 2}
# Val C-Index: 0.6716090425531915
#
# [79/800] {'n_estimators': 54, 'max_depth': 4, 'min_samples_leaf': 3}
# Val C-Index: 0.6687333776595744
#
# [80/800] {'n_estimators': 54, 'max_depth': 4, 'min_samples_leaf': 4}
# Val C-Index: 0.6641123670212766
#
# [81/800] {'n_estimators': 55, 'max_depth': 1, 'min_samples_leaf': 1}
# Val C-Index: 0.6636303191489362
# [82/800] {'n_estimators': 55, 'max_depth': 1, 'min_samples_leaf': 2}
# Val C-Index: 0.6636303191489362
#
# [83/800] {'n_estimators': 55, 'max_depth': 1, 'min_samples_leaf': 3}
# Val C-Index: 0.6636303191489362
#
# [84/800] {'n_estimators': 55, 'max_depth': 1, 'min_samples_leaf': 4}
# Val C-Index: 0.6636303191489362
#
# [85/800] {'n_estimators': 55, 'max_depth': 2, 'min_samples_leaf': 1}
# Val C-Index: 0.6584441489361702
#
# [86/800] {'n_estimators': 55, 'max_depth': 2, 'min_samples_leaf': 2}
# Val C-Index: 0.6584441489361702
#
# [87/800] {'n_estimators': 55, 'max_depth': 2, 'min_samples_leaf': 3}
# Val C-Index: 0.6590757978723404
#
# [88/800] {'n_estimators': 55, 'max_depth': 2, 'min_samples_leaf': 4}
# Val C-Index: 0.6594581117021276
#
# [89/800] {'n_estimators': 55, 'max_depth': 3, 'min_samples_leaf': 1}
# Val C-Index: 0.6724401595744681
#
# [90/800] {'n_estimators': 55, 'max_depth': 3, 'min_samples_leaf': 2}
# Val C-Index: 0.6722739361702128
#
# [91/800] {'n_estimators': 55, 'max_depth': 3, 'min_samples_leaf': 3}
# Val C-Index: 0.6724900265957446
#
# [92/800] {'n_estimators': 55, 'max_depth': 3, 'min_samples_leaf': 4}
# Val C-Index: 0.6726063829787234
#
# [93/800] {'n_estimators': 55, 'max_depth': 4, 'min_samples_leaf': 1}
# Val C-Index: 0.6691489361702128
#
# [94/800] {'n_estimators': 55, 'max_depth': 4, 'min_samples_leaf': 2}
# Val C-Index: 0.6712433510638298
#
# [95/800] {'n_estimators': 55, 'max_depth': 4, 'min_samples_leaf': 3}
# Val C-Index: 0.6684840425531915
#
# [96/800] {'n_estimators': 55, 'max_depth': 4, 'min_samples_leaf': 4}
# Val C-Index: 0.6640458776595745
#
# [97/800] {'n_estimators': 56, 'max_depth': 1, 'min_samples_leaf': 1}
# Val C-Index: 0.6653257978723405
#
# [98/800] {'n_estimators': 56, 'max_depth': 1, 'min_samples_leaf': 2}
# Val C-Index: 0.6653257978723405
#
# [99/800] {'n_estimators': 56, 'max_depth': 1, 'min_samples_leaf': 3}
# Val C-Index: 0.6653257978723405
#
# [100/800] {'n_estimators': 56, 'max_depth': 1, 'min_samples_leaf': 4}
# Val C-Index: 0.6653257978723405
#
# [101/800] {'n_estimators': 56, 'max_depth': 2, 'min_samples_leaf': 1}
# Val C-Index: 0.6596742021276596
#
# [102/800] {'n_estimators': 56, 'max_depth': 2, 'min_samples_leaf': 2}
# Val C-Index: 0.6596742021276596
#
# [103/800] {'n_estimators': 56, 'max_depth': 2, 'min_samples_leaf': 3}
# Val C-Index: 0.6600731382978723
#
# [104/800] {'n_estimators': 56, 'max_depth': 2, 'min_samples_leaf': 4}
# Val C-Index: 0.6602892287234042
#
# [105/800] {'n_estimators': 56, 'max_depth': 3, 'min_samples_leaf': 1}
# Val C-Index: 0.6732546542553192
#
# [106/800] {'n_estimators': 56, 'max_depth': 3, 'min_samples_leaf': 2}
# Val C-Index: 0.6730219414893617
#
# [107/800] {'n_estimators': 56, 'max_depth': 3, 'min_samples_leaf': 3}
# Val C-Index: 0.6731050531914894
#
# [108/800] {'n_estimators': 56, 'max_depth': 3, 'min_samples_leaf': 4}
# Val C-Index: 0.6734707446808511
#
# [109/800] {'n_estimators': 56, 'max_depth': 4, 'min_samples_leaf': 1}
# Val C-Index: 0.6678856382978723
#
# [110/800] {'n_estimators': 56, 'max_depth': 4, 'min_samples_leaf': 2}
# Val C-Index: 0.6706615691489362
#
# [111/800] {'n_estimators': 56, 'max_depth': 4, 'min_samples_leaf': 3}
# Val C-Index: 0.6678357712765958
#
# [112/800] {'n_estimators': 56, 'max_depth': 4, 'min_samples_leaf': 4}
# Val C-Index: 0.6631648936170212
#
# [113/800] {'n_estimators': 57, 'max_depth': 1, 'min_samples_leaf': 1}
# Val C-Index: 0.6674202127659574
#
# [114/800] {'n_estimators': 57, 'max_depth': 1, 'min_samples_leaf': 2}
# Val C-Index: 0.6674202127659574
#
# [115/800] {'n_estimators': 57, 'max_depth': 1, 'min_samples_leaf': 3}
# Val C-Index: 0.6674202127659574
#
# [116/800] {'n_estimators': 57, 'max_depth': 1, 'min_samples_leaf': 4}
# Val C-Index: 0.6674202127659574
#
# [117/800] {'n_estimators': 57, 'max_depth': 2, 'min_samples_leaf': 1}
# Val C-Index: 0.6624168882978724
#
# [118/800] {'n_estimators': 57, 'max_depth': 2, 'min_samples_leaf': 2}
# Val C-Index: 0.6624168882978724
#
# [119/800] {'n_estimators': 57, 'max_depth': 2, 'min_samples_leaf': 3}
# Val C-Index: 0.6626994680851064
#
# [120/800] {'n_estimators': 57, 'max_depth': 2, 'min_samples_leaf': 4}
# Val C-Index: 0.6627825797872341
#
# [121/800] {'n_estimators': 57, 'max_depth': 3, 'min_samples_leaf': 1}
# Val C-Index: 0.6748005319148936
#
# [122/800] {'n_estimators': 57, 'max_depth': 3, 'min_samples_leaf': 2}
# Val C-Index: 0.6746841755319148
#
# [123/800] {'n_estimators': 57, 'max_depth': 3, 'min_samples_leaf': 3}
# Val C-Index: 0.6748337765957447
#
# [124/800] {'n_estimators': 57, 'max_depth': 3, 'min_samples_leaf': 4}
# Val C-Index: 0.6755817819148936
#
# [125/800] {'n_estimators': 57, 'max_depth': 4, 'min_samples_leaf': 1}
# Val C-Index: 0.6698803191489362
#
# [126/800] {'n_estimators': 57, 'max_depth': 4, 'min_samples_leaf': 2}
# Val C-Index: 0.6713264627659574
#
# [127/800] {'n_estimators': 57, 'max_depth': 4, 'min_samples_leaf': 3}
# Val C-Index: 0.6693151595744681
#
# [128/800] {'n_estimators': 57, 'max_depth': 4, 'min_samples_leaf': 4}
# Val C-Index: 0.6647440159574468
#
# [129/800] {'n_estimators': 58, 'max_depth': 1, 'min_samples_leaf': 1}
# Val C-Index: 0.6663896276595744
#
# [130/800] {'n_estimators': 58, 'max_depth': 1, 'min_samples_leaf': 2}
# Val C-Index: 0.6663896276595744
#
# [131/800] {'n_estimators': 58, 'max_depth': 1, 'min_samples_leaf': 3}
# Val C-Index: 0.6663896276595744
#
# [132/800] {'n_estimators': 58, 'max_depth': 1, 'min_samples_leaf': 4}
# Val C-Index: 0.6663896276595744
#
# [133/800] {'n_estimators': 58, 'max_depth': 2, 'min_samples_leaf': 1}
# Val C-Index: 0.6615359042553192
#
# [134/800] {'n_estimators': 58, 'max_depth': 2, 'min_samples_leaf': 2}
# Val C-Index: 0.6615359042553192
#
# [135/800] {'n_estimators': 58, 'max_depth': 2, 'min_samples_leaf': 3}
# Val C-Index: 0.6618184840425532
#
# [136/800] {'n_estimators': 58, 'max_depth': 2, 'min_samples_leaf': 4}
# Val C-Index: 0.6619015957446809
#
# [137/800] {'n_estimators': 58, 'max_depth': 3, 'min_samples_leaf': 1}
# Val C-Index: 0.6750166223404256
#
# [138/800] {'n_estimators': 58, 'max_depth': 3, 'min_samples_leaf': 2}
# Val C-Index: 0.6747672872340426
#
# [139/800] {'n_estimators': 58, 'max_depth': 3, 'min_samples_leaf': 3}
# Val C-Index: 0.675
#
# [140/800] {'n_estimators': 58, 'max_depth': 3, 'min_samples_leaf': 4}
# Val C-Index: 0.675249335106383
#
# [141/800] {'n_estimators': 58, 'max_depth': 4, 'min_samples_leaf': 1}
# Val C-Index: 0.6695478723404256
#
# [142/800] {'n_estimators': 58, 'max_depth': 4, 'min_samples_leaf': 2}
# Val C-Index: 0.6724900265957446
#
# [143/800] {'n_estimators': 58, 'max_depth': 4, 'min_samples_leaf': 3}
# Val C-Index: 0.6696642287234043
#
# [144/800] {'n_estimators': 58, 'max_depth': 4, 'min_samples_leaf': 4}
# Val C-Index: 0.6654587765957447
#
# [145/800] {'n_estimators': 59, 'max_depth': 1, 'min_samples_leaf': 1}
# Val C-Index: 0.6679853723404255
#
# [146/800] {'n_estimators': 59, 'max_depth': 1, 'min_samples_leaf': 2}
# Val C-Index: 0.6679853723404255
#
# [147/800] {'n_estimators': 59, 'max_depth': 1, 'min_samples_leaf': 3}
# Val C-Index: 0.6679853723404255
#
# [148/800] {'n_estimators': 59, 'max_depth': 1, 'min_samples_leaf': 4}
# Val C-Index: 0.6679853723404255
#
# [149/800] {'n_estimators': 59, 'max_depth': 2, 'min_samples_leaf': 1}
# Val C-Index: 0.6616356382978723
#
# [150/800] {'n_estimators': 59, 'max_depth': 2, 'min_samples_leaf': 2}
# Val C-Index: 0.6616356382978723
#
# [151/800] {'n_estimators': 59, 'max_depth': 2, 'min_samples_leaf': 3}
# Val C-Index: 0.6619847074468085
#
# [152/800] {'n_estimators': 59, 'max_depth': 2, 'min_samples_leaf': 4}
# Val C-Index: 0.6620511968085107
#
# [153/800] {'n_estimators': 59, 'max_depth': 3, 'min_samples_leaf': 1}
# Val C-Index: 0.6748836436170212
#
# [154/800] {'n_estimators': 59, 'max_depth': 3, 'min_samples_leaf': 2}
# Val C-Index: 0.6748171542553192
#
# [155/800] {'n_estimators': 59, 'max_depth': 3, 'min_samples_leaf': 3}
# Val C-Index: 0.674750664893617
#
# [156/800] {'n_estimators': 59, 'max_depth': 3, 'min_samples_leaf': 4}
# Val C-Index: 0.6755817819148936
#
# [157/800] {'n_estimators': 59, 'max_depth': 4, 'min_samples_leaf': 1}
# Val C-Index: 0.668999335106383
#
# [158/800] {'n_estimators': 59, 'max_depth': 4, 'min_samples_leaf': 2}
# Val C-Index: 0.6719913563829787
#
# [159/800] {'n_estimators': 59, 'max_depth': 4, 'min_samples_leaf': 3}
# Val C-Index: 0.6699800531914893
#
# [160/800] {'n_estimators': 59, 'max_depth': 4, 'min_samples_leaf': 4}
# Val C-Index: 0.6659906914893617
#
# [161/800] {'n_estimators': 60, 'max_depth': 1, 'min_samples_leaf': 1}
# Val C-Index: 0.6689660904255319
# [162/800] {'n_estimators': 60, 'max_depth': 1, 'min_samples_leaf': 2}
# Val C-Index: 0.6689660904255319
#
# [163/800] {'n_estimators': 60, 'max_depth': 1, 'min_samples_leaf': 3}
# Val C-Index: 0.6689660904255319
#
# [164/800] {'n_estimators': 60, 'max_depth': 1, 'min_samples_leaf': 4}
# Val C-Index: 0.6689660904255319
#
# [165/800] {'n_estimators': 60, 'max_depth': 2, 'min_samples_leaf': 1}
# Val C-Index: 0.662217420212766
#
# [166/800] {'n_estimators': 60, 'max_depth': 2, 'min_samples_leaf': 2}
# Val C-Index: 0.662217420212766
#
# [167/800] {'n_estimators': 60, 'max_depth': 2, 'min_samples_leaf': 3}
# Val C-Index: 0.662749335106383
#
# [168/800] {'n_estimators': 60, 'max_depth': 2, 'min_samples_leaf': 4}
# Val C-Index: 0.6627659574468086
#
# [169/800] {'n_estimators': 60, 'max_depth': 3, 'min_samples_leaf': 1}
# Val C-Index: 0.6762965425531915
#
# [170/800] {'n_estimators': 60, 'max_depth': 3, 'min_samples_leaf': 2}
# Val C-Index: 0.6759807180851064
#
# [171/800] {'n_estimators': 60, 'max_depth': 3, 'min_samples_leaf': 3}
# Val C-Index: 0.6762300531914893
#
# [172/800] {'n_estimators': 60, 'max_depth': 3, 'min_samples_leaf': 4}
# Val C-Index: 0.6768783244680852
#
# [173/800] {'n_estimators': 60, 'max_depth': 4, 'min_samples_leaf': 1}
# Val C-Index: 0.6699468085106383
#
# [174/800] {'n_estimators': 60, 'max_depth': 4, 'min_samples_leaf': 2}
# Val C-Index: 0.6727559840425532
#
# [175/800] {'n_estimators': 60, 'max_depth': 4, 'min_samples_leaf': 3}
# Val C-Index: 0.6703789893617021
#
# [176/800] {'n_estimators': 60, 'max_depth': 4, 'min_samples_leaf': 4}
# Val C-Index: 0.6674035904255319
#
# [177/800] {'n_estimators': 61, 'max_depth': 1, 'min_samples_leaf': 1}
# Val C-Index: 0.6657912234042553
#
# [178/800] {'n_estimators': 61, 'max_depth': 1, 'min_samples_leaf': 2}
# Val C-Index: 0.6657912234042553
#
# [179/800] {'n_estimators': 61, 'max_depth': 1, 'min_samples_leaf': 3}
# Val C-Index: 0.6657912234042553
#
# [180/800] {'n_estimators': 61, 'max_depth': 1, 'min_samples_leaf': 4}
# Val C-Index: 0.6657912234042553
#
# [181/800] {'n_estimators': 61, 'max_depth': 2, 'min_samples_leaf': 1}
# Val C-Index: 0.6624002659574468
#
# [182/800] {'n_estimators': 61, 'max_depth': 2, 'min_samples_leaf': 2}
# Val C-Index: 0.6624002659574468
#
# [183/800] {'n_estimators': 61, 'max_depth': 2, 'min_samples_leaf': 3}
# Val C-Index: 0.6630651595744681
#
# [184/800] {'n_estimators': 61, 'max_depth': 2, 'min_samples_leaf': 4}
# Val C-Index: 0.6631648936170212
#
# [185/800] {'n_estimators': 61, 'max_depth': 3, 'min_samples_leaf': 1}
# Val C-Index: 0.6756815159574469
#
# [186/800] {'n_estimators': 61, 'max_depth': 3, 'min_samples_leaf': 2}
# Val C-Index: 0.675531914893617
#
# [187/800] {'n_estimators': 61, 'max_depth': 3, 'min_samples_leaf': 3}
# Val C-Index: 0.6760472074468085
#
# [188/800] {'n_estimators': 61, 'max_depth': 3, 'min_samples_leaf': 4}
# Val C-Index: 0.6761968085106383
#
# [189/800] {'n_estimators': 61, 'max_depth': 4, 'min_samples_leaf': 1}
# Val C-Index: 0.6694481382978723
#
# [190/800] {'n_estimators': 61, 'max_depth': 4, 'min_samples_leaf': 2}
# Val C-Index: 0.6719082446808511
#
# [191/800] {'n_estimators': 61, 'max_depth': 4, 'min_samples_leaf': 3}
# Val C-Index: 0.669813829787234
#
# [192/800] {'n_estimators': 61, 'max_depth': 4, 'min_samples_leaf': 4}
# Val C-Index: 0.6671708776595745
#
# [193/800] {'n_estimators': 62, 'max_depth': 1, 'min_samples_leaf': 1}
# Val C-Index: 0.6659408244680851
#
# [194/800] {'n_estimators': 62, 'max_depth': 1, 'min_samples_leaf': 2}
# Val C-Index: 0.6659408244680851
#
# [195/800] {'n_estimators': 62, 'max_depth': 1, 'min_samples_leaf': 3}
# Val C-Index: 0.6659408244680851
#
# [196/800] {'n_estimators': 62, 'max_depth': 1, 'min_samples_leaf': 4}
# Val C-Index: 0.6659408244680851
#
# [197/800] {'n_estimators': 62, 'max_depth': 2, 'min_samples_leaf': 1}
# Val C-Index: 0.662749335106383
#
# [198/800] {'n_estimators': 62, 'max_depth': 2, 'min_samples_leaf': 2}
# Val C-Index: 0.662749335106383
#
# [199/800] {'n_estimators': 62, 'max_depth': 2, 'min_samples_leaf': 3}
# Val C-Index: 0.6633477393617021
#
# [200/800] {'n_estimators': 62, 'max_depth': 2, 'min_samples_leaf': 4}
# Val C-Index: 0.6634474734042554
#
# [201/800] {'n_estimators': 62, 'max_depth': 3, 'min_samples_leaf': 1}
# Val C-Index: 0.6765458776595744
#
# [202/800] {'n_estimators': 62, 'max_depth': 3, 'min_samples_leaf': 2}
# Val C-Index: 0.6764461436170213
#
# [203/800] {'n_estimators': 62, 'max_depth': 3, 'min_samples_leaf': 3}
# Val C-Index: 0.6766954787234043
#
# [204/800] {'n_estimators': 62, 'max_depth': 3, 'min_samples_leaf': 4}
# Val C-Index: 0.6773769946808511
#
# [205/800] {'n_estimators': 62, 'max_depth': 4, 'min_samples_leaf': 1}
# Val C-Index: 0.6696309840425532
#
# [206/800] {'n_estimators': 62, 'max_depth': 4, 'min_samples_leaf': 2}
# Val C-Index: 0.6726728723404255
#
# [207/800] {'n_estimators': 62, 'max_depth': 4, 'min_samples_leaf': 3}
# Val C-Index: 0.6704953457446808
#
# [208/800] {'n_estimators': 62, 'max_depth': 4, 'min_samples_leaf': 4}
# Val C-Index: 0.6680518617021277
#
# [209/800] {'n_estimators': 63, 'max_depth': 1, 'min_samples_leaf': 1}
# Val C-Index: 0.6633477393617021
#
# [210/800] {'n_estimators': 63, 'max_depth': 1, 'min_samples_leaf': 2}
# Val C-Index: 0.6633477393617021
#
# [211/800] {'n_estimators': 63, 'max_depth': 1, 'min_samples_leaf': 3}
# Val C-Index: 0.6633477393617021
#
# [212/800] {'n_estimators': 63, 'max_depth': 1, 'min_samples_leaf': 4}
# Val C-Index: 0.6633477393617021
#
# [213/800] {'n_estimators': 63, 'max_depth': 2, 'min_samples_leaf': 1}
# Val C-Index: 0.661469414893617
#
# [214/800] {'n_estimators': 63, 'max_depth': 2, 'min_samples_leaf': 2}
# Val C-Index: 0.661469414893617
#
# [215/800] {'n_estimators': 63, 'max_depth': 2, 'min_samples_leaf': 3}
# Val C-Index: 0.6618683510638298
#
# [216/800] {'n_estimators': 63, 'max_depth': 2, 'min_samples_leaf': 4}
# Val C-Index: 0.6621509308510638
#
# [217/800] {'n_estimators': 63, 'max_depth': 3, 'min_samples_leaf': 1}
# Val C-Index: 0.6773936170212767
#
# [218/800] {'n_estimators': 63, 'max_depth': 3, 'min_samples_leaf': 2}
# Val C-Index: 0.6772606382978723
#
# [219/800] {'n_estimators': 63, 'max_depth': 3, 'min_samples_leaf': 3}
# Val C-Index: 0.6773105053191489
#
# [220/800] {'n_estimators': 63, 'max_depth': 3, 'min_samples_leaf': 4}
# Val C-Index: 0.6777426861702127
#
# [221/800] {'n_estimators': 63, 'max_depth': 4, 'min_samples_leaf': 1}
# Val C-Index: 0.6687998670212766
#
# [222/800] {'n_estimators': 63, 'max_depth': 4, 'min_samples_leaf': 2}
# Val C-Index: 0.6719082446808511
#
# [223/800] {'n_estimators': 63, 'max_depth': 4, 'min_samples_leaf': 3}
# Val C-Index: 0.6698969414893617
#
# [224/800] {'n_estimators': 63, 'max_depth': 4, 'min_samples_leaf': 4}
# Val C-Index: 0.6687333776595744
#
# [225/800] {'n_estimators': 64, 'max_depth': 1, 'min_samples_leaf': 1}
# Val C-Index: 0.6628656914893617
#
# [226/800] {'n_estimators': 64, 'max_depth': 1, 'min_samples_leaf': 2}
# Val C-Index: 0.6628656914893617
#
# [227/800] {'n_estimators': 64, 'max_depth': 1, 'min_samples_leaf': 3}
# Val C-Index: 0.6628656914893617
#
# [228/800] {'n_estimators': 64, 'max_depth': 1, 'min_samples_leaf': 4}
# Val C-Index: 0.6628656914893617
#
# [229/800] {'n_estimators': 64, 'max_depth': 2, 'min_samples_leaf': 1}
# Val C-Index: 0.660970744680851
#
# [230/800] {'n_estimators': 64, 'max_depth': 2, 'min_samples_leaf': 2}
# Val C-Index: 0.660970744680851
#
# [231/800] {'n_estimators': 64, 'max_depth': 2, 'min_samples_leaf': 3}
# Val C-Index: 0.6613364361702128
#
# [232/800] {'n_estimators': 64, 'max_depth': 2, 'min_samples_leaf': 4}
# Val C-Index: 0.6616023936170212
#
# [233/800] {'n_estimators': 64, 'max_depth': 3, 'min_samples_leaf': 1}
# Val C-Index: 0.6761635638297873
#
# [234/800] {'n_estimators': 64, 'max_depth': 3, 'min_samples_leaf': 2}
# Val C-Index: 0.6759807180851064
#
# [235/800] {'n_estimators': 64, 'max_depth': 3, 'min_samples_leaf': 3}
# Val C-Index: 0.6761801861702128
#
# [236/800] {'n_estimators': 64, 'max_depth': 3, 'min_samples_leaf': 4}
# Val C-Index: 0.6762300531914893
#
# [237/800] {'n_estimators': 64, 'max_depth': 4, 'min_samples_leaf': 1}
# Val C-Index: 0.6690824468085106
#
# [238/800] {'n_estimators': 64, 'max_depth': 4, 'min_samples_leaf': 2}
# Val C-Index: 0.6725232712765957
#
# [239/800] {'n_estimators': 64, 'max_depth': 4, 'min_samples_leaf': 3}
# Val C-Index: 0.6715757978723405
#
# [240/800] {'n_estimators': 64, 'max_depth': 4, 'min_samples_leaf': 4}
# Val C-Index: 0.6697639627659574
#
# [241/800] {'n_estimators': 65, 'max_depth': 1, 'min_samples_leaf': 1}
# Val C-Index: 0.6635139627659574
# [242/800] {'n_estimators': 65, 'max_depth': 1, 'min_samples_leaf': 2}
# Val C-Index: 0.6635139627659574
#
# [243/800] {'n_estimators': 65, 'max_depth': 1, 'min_samples_leaf': 3}
# Val C-Index: 0.6635139627659574
#
# [244/800] {'n_estimators': 65, 'max_depth': 1, 'min_samples_leaf': 4}
# Val C-Index: 0.6635139627659574
#
# [245/800] {'n_estimators': 65, 'max_depth': 2, 'min_samples_leaf': 1}
# Val C-Index: 0.6608377659574468
#
# [246/800] {'n_estimators': 65, 'max_depth': 2, 'min_samples_leaf': 2}
# Val C-Index: 0.6608377659574468
#
# [247/800] {'n_estimators': 65, 'max_depth': 2, 'min_samples_leaf': 3}
# Val C-Index: 0.6614361702127659
#
# [248/800] {'n_estimators': 65, 'max_depth': 2, 'min_samples_leaf': 4}
# Val C-Index: 0.6617021276595745
#
# [249/800] {'n_estimators': 65, 'max_depth': 3, 'min_samples_leaf': 1}
# Val C-Index: 0.6763630319148937
#
# [250/800] {'n_estimators': 65, 'max_depth': 3, 'min_samples_leaf': 2}
# Val C-Index: 0.6761303191489362
#
# [251/800] {'n_estimators': 65, 'max_depth': 3, 'min_samples_leaf': 3}
# Val C-Index: 0.6756815159574469
#
# [252/800] {'n_estimators': 65, 'max_depth': 3, 'min_samples_leaf': 4}
# Val C-Index: 0.6753989361702127
#
# [253/800] {'n_estimators': 65, 'max_depth': 4, 'min_samples_leaf': 1}
# Val C-Index: 0.6695811170212767
#
# [254/800] {'n_estimators': 65, 'max_depth': 4, 'min_samples_leaf': 2}
# Val C-Index: 0.6731715425531914
#
# [255/800] {'n_estimators': 65, 'max_depth': 4, 'min_samples_leaf': 3}
# Val C-Index: 0.6710771276595745
#
# [256/800] {'n_estimators': 65, 'max_depth': 4, 'min_samples_leaf': 4}
# Val C-Index: 0.6694148936170212
#
# [257/800] {'n_estimators': 66, 'max_depth': 1, 'min_samples_leaf': 1}
# Val C-Index: 0.6639128989361702
#
# [258/800] {'n_estimators': 66, 'max_depth': 1, 'min_samples_leaf': 2}
# Val C-Index: 0.6639128989361702
#
# [259/800] {'n_estimators': 66, 'max_depth': 1, 'min_samples_leaf': 3}
# Val C-Index: 0.6639128989361702
#
# [260/800] {'n_estimators': 66, 'max_depth': 1, 'min_samples_leaf': 4}
# Val C-Index: 0.6639128989361702
#
# [261/800] {'n_estimators': 66, 'max_depth': 2, 'min_samples_leaf': 1}
# Val C-Index: 0.6604554521276595
#
# [262/800] {'n_estimators': 66, 'max_depth': 2, 'min_samples_leaf': 2}
# Val C-Index: 0.6604554521276595
#
# [263/800] {'n_estimators': 66, 'max_depth': 2, 'min_samples_leaf': 3}
# Val C-Index: 0.660970744680851
#
# [264/800] {'n_estimators': 66, 'max_depth': 2, 'min_samples_leaf': 4}
# Val C-Index: 0.6612200797872341
#
# [265/800] {'n_estimators': 66, 'max_depth': 3, 'min_samples_leaf': 1}
# Val C-Index: 0.6764793882978724
#
# [266/800] {'n_estimators': 66, 'max_depth': 3, 'min_samples_leaf': 2}
# Val C-Index: 0.6764960106382979
#
# [267/800] {'n_estimators': 66, 'max_depth': 3, 'min_samples_leaf': 3}
# Val C-Index: 0.6757480053191489
#
# [268/800] {'n_estimators': 66, 'max_depth': 3, 'min_samples_leaf': 4}
# Val C-Index: 0.6761303191489362
#
# [269/800] {'n_estimators': 66, 'max_depth': 4, 'min_samples_leaf': 1}
# Val C-Index: 0.6686336436170213
#
# [270/800] {'n_estimators': 66, 'max_depth': 4, 'min_samples_leaf': 2}
# Val C-Index: 0.6716755319148936
#
# [271/800] {'n_estimators': 66, 'max_depth': 4, 'min_samples_leaf': 3}
# Val C-Index: 0.6702626329787233
#
# [272/800] {'n_estimators': 66, 'max_depth': 4, 'min_samples_leaf': 4}
# Val C-Index: 0.6691156914893617
#
# [273/800] {'n_estimators': 67, 'max_depth': 1, 'min_samples_leaf': 1}
# Val C-Index: 0.6642619680851064
#
# [274/800] {'n_estimators': 67, 'max_depth': 1, 'min_samples_leaf': 2}
# Val C-Index: 0.6642619680851064
#
# [275/800] {'n_estimators': 67, 'max_depth': 1, 'min_samples_leaf': 3}
# Val C-Index: 0.6642619680851064
#
# [276/800] {'n_estimators': 67, 'max_depth': 1, 'min_samples_leaf': 4}
# Val C-Index: 0.6642619680851064
#
# [277/800] {'n_estimators': 67, 'max_depth': 2, 'min_samples_leaf': 1}
# Val C-Index: 0.6618184840425532
#
# [278/800] {'n_estimators': 67, 'max_depth': 2, 'min_samples_leaf': 2}
# Val C-Index: 0.6618184840425532
#
# [279/800] {'n_estimators': 67, 'max_depth': 2, 'min_samples_leaf': 3}
# Val C-Index: 0.6620844414893617
#
# [280/800] {'n_estimators': 67, 'max_depth': 2, 'min_samples_leaf': 4}
# Val C-Index: 0.6623836436170213
#
# [281/800] {'n_estimators': 67, 'max_depth': 3, 'min_samples_leaf': 1}
# Val C-Index: 0.6769946808510638
#
# [282/800] {'n_estimators': 67, 'max_depth': 3, 'min_samples_leaf': 2}
# Val C-Index: 0.6768450797872341
#
# [283/800] {'n_estimators': 67, 'max_depth': 3, 'min_samples_leaf': 3}
# Val C-Index: 0.676279920212766
#
# [284/800] {'n_estimators': 67, 'max_depth': 3, 'min_samples_leaf': 4}
# Val C-Index: 0.675997340425532
#
# [285/800] {'n_estimators': 67, 'max_depth': 4, 'min_samples_leaf': 1}
# Val C-Index: 0.6684175531914893
#
# [286/800] {'n_estimators': 67, 'max_depth': 4, 'min_samples_leaf': 2}
# Val C-Index: 0.6728723404255319
#
# [287/800] {'n_estimators': 67, 'max_depth': 4, 'min_samples_leaf': 3}
# Val C-Index: 0.6709940159574468
#
# [288/800] {'n_estimators': 67, 'max_depth': 4, 'min_samples_leaf': 4}
# Val C-Index: 0.6697639627659574
#
# [289/800] {'n_estimators': 68, 'max_depth': 1, 'min_samples_leaf': 1}
# Val C-Index: 0.6641954787234042
#
# [290/800] {'n_estimators': 68, 'max_depth': 1, 'min_samples_leaf': 2}
# Val C-Index: 0.6641954787234042
#
# [291/800] {'n_estimators': 68, 'max_depth': 1, 'min_samples_leaf': 3}
# Val C-Index: 0.6641954787234042
#
# [292/800] {'n_estimators': 68, 'max_depth': 1, 'min_samples_leaf': 4}
# Val C-Index: 0.6641954787234042
#
# [293/800] {'n_estimators': 68, 'max_depth': 2, 'min_samples_leaf': 1}
# Val C-Index: 0.6605551861702128
#
# [294/800] {'n_estimators': 68, 'max_depth': 2, 'min_samples_leaf': 2}
# Val C-Index: 0.6605551861702128
#
# [295/800] {'n_estimators': 68, 'max_depth': 2, 'min_samples_leaf': 3}
# Val C-Index: 0.6609208776595744
#
# [296/800] {'n_estimators': 68, 'max_depth': 2, 'min_samples_leaf': 4}
# Val C-Index: 0.6612034574468085
#
# [297/800] {'n_estimators': 68, 'max_depth': 3, 'min_samples_leaf': 1}
# Val C-Index: 0.6773603723404256
#
# [298/800] {'n_estimators': 68, 'max_depth': 3, 'min_samples_leaf': 2}
# Val C-Index: 0.6773936170212767
#
# [299/800] {'n_estimators': 68, 'max_depth': 3, 'min_samples_leaf': 3}
# Val C-Index: 0.6770113031914894
#
# [300/800] {'n_estimators': 68, 'max_depth': 3, 'min_samples_leaf': 4}
# Val C-Index: 0.6766123670212766
#
# [301/800] {'n_estimators': 68, 'max_depth': 4, 'min_samples_leaf': 1}
# Val C-Index: 0.6695644946808511
#
# [302/800] {'n_estimators': 68, 'max_depth': 4, 'min_samples_leaf': 2}
# Val C-Index: 0.6728390957446808
#
# [303/800] {'n_estimators': 68, 'max_depth': 4, 'min_samples_leaf': 3}
# Val C-Index: 0.6715259308510638
#
# [304/800] {'n_estimators': 68, 'max_depth': 4, 'min_samples_leaf': 4}
# Val C-Index: 0.6699468085106383
#
# [305/800] {'n_estimators': 69, 'max_depth': 1, 'min_samples_leaf': 1}
# Val C-Index: 0.6635970744680851
#
# [306/800] {'n_estimators': 69, 'max_depth': 1, 'min_samples_leaf': 2}
# Val C-Index: 0.6635970744680851
#
# [307/800] {'n_estimators': 69, 'max_depth': 1, 'min_samples_leaf': 3}
# Val C-Index: 0.6635970744680851
#
# [308/800] {'n_estimators': 69, 'max_depth': 1, 'min_samples_leaf': 4}
# Val C-Index: 0.6635970744680851
#
# [309/800] {'n_estimators': 69, 'max_depth': 2, 'min_samples_leaf': 1}
# Val C-Index: 0.6607047872340426
#
# [310/800] {'n_estimators': 69, 'max_depth': 2, 'min_samples_leaf': 2}
# Val C-Index: 0.6607047872340426
#
# [311/800] {'n_estimators': 69, 'max_depth': 2, 'min_samples_leaf': 3}
# Val C-Index: 0.660970744680851
#
# [312/800] {'n_estimators': 69, 'max_depth': 2, 'min_samples_leaf': 4}
# Val C-Index: 0.6612699468085106
#
# [313/800] {'n_estimators': 69, 'max_depth': 3, 'min_samples_leaf': 1}
# Val C-Index: 0.6773271276595745
#
# [314/800] {'n_estimators': 69, 'max_depth': 3, 'min_samples_leaf': 2}
# Val C-Index: 0.6774102393617021
#
# [315/800] {'n_estimators': 69, 'max_depth': 3, 'min_samples_leaf': 3}
# Val C-Index: 0.6762965425531915
#
# [316/800] {'n_estimators': 69, 'max_depth': 3, 'min_samples_leaf': 4}
# Val C-Index: 0.6765625
#
# [317/800] {'n_estimators': 69, 'max_depth': 4, 'min_samples_leaf': 1}
# Val C-Index: 0.6693982712765958
#
# [318/800] {'n_estimators': 69, 'max_depth': 4, 'min_samples_leaf': 2}
# Val C-Index: 0.6722739361702128
#
# [319/800] {'n_estimators': 69, 'max_depth': 4, 'min_samples_leaf': 3}
# Val C-Index: 0.6712932180851063
#
# [320/800] {'n_estimators': 69, 'max_depth': 4, 'min_samples_leaf': 4}
# Val C-Index: 0.6699135638297873
#
# [321/800] {'n_estimators': 70, 'max_depth': 1, 'min_samples_leaf': 1}
# Val C-Index: 0.6641456117021277
# [322/800] {'n_estimators': 70, 'max_depth': 1, 'min_samples_leaf': 2}
# Val C-Index: 0.6641456117021277
#
# [323/800] {'n_estimators': 70, 'max_depth': 1, 'min_samples_leaf': 3}
# Val C-Index: 0.6641456117021277
#
# [324/800] {'n_estimators': 70, 'max_depth': 1, 'min_samples_leaf': 4}
# Val C-Index: 0.6641456117021277
#
# [325/800] {'n_estimators': 70, 'max_depth': 2, 'min_samples_leaf': 1}
# Val C-Index: 0.6611203457446808
#
# [326/800] {'n_estimators': 70, 'max_depth': 2, 'min_samples_leaf': 2}
# Val C-Index: 0.6611203457446808
#
# [327/800] {'n_estimators': 70, 'max_depth': 2, 'min_samples_leaf': 3}
# Val C-Index: 0.6614195478723405
#
# [328/800] {'n_estimators': 70, 'max_depth': 2, 'min_samples_leaf': 4}
# Val C-Index: 0.6617519946808511
#
# [329/800] {'n_estimators': 70, 'max_depth': 3, 'min_samples_leaf': 1}
# Val C-Index: 0.6782579787234042
#
# [330/800] {'n_estimators': 70, 'max_depth': 3, 'min_samples_leaf': 2}
# Val C-Index: 0.6784242021276595
#
# [331/800] {'n_estimators': 70, 'max_depth': 3, 'min_samples_leaf': 3}
# Val C-Index: 0.6777925531914893
#
# [332/800] {'n_estimators': 70, 'max_depth': 3, 'min_samples_leaf': 4}
# Val C-Index: 0.6771609042553192
#
# [333/800] {'n_estimators': 70, 'max_depth': 4, 'min_samples_leaf': 1}
# Val C-Index: 0.670096409574468
#
# [334/800] {'n_estimators': 70, 'max_depth': 4, 'min_samples_leaf': 2}
# Val C-Index: 0.6732380319148936
#
# [335/800] {'n_estimators': 70, 'max_depth': 4, 'min_samples_leaf': 3}
# Val C-Index: 0.6725232712765957
#
# [336/800] {'n_estimators': 70, 'max_depth': 4, 'min_samples_leaf': 4}
# Val C-Index: 0.6705452127659575
#
# [337/800] {'n_estimators': 71, 'max_depth': 1, 'min_samples_leaf': 1}
# Val C-Index: 0.6640292553191489
#
# [338/800] {'n_estimators': 71, 'max_depth': 1, 'min_samples_leaf': 2}
# Val C-Index: 0.6640292553191489
#
# [339/800] {'n_estimators': 71, 'max_depth': 1, 'min_samples_leaf': 3}
# Val C-Index: 0.6640292553191489
#
# [340/800] {'n_estimators': 71, 'max_depth': 1, 'min_samples_leaf': 4}
# Val C-Index: 0.6640292553191489
#
# [341/800] {'n_estimators': 71, 'max_depth': 2, 'min_samples_leaf': 1}
# Val C-Index: 0.6619015957446809
#
# [342/800] {'n_estimators': 71, 'max_depth': 2, 'min_samples_leaf': 2}
# Val C-Index: 0.6619015957446809
#
# [343/800] {'n_estimators': 71, 'max_depth': 2, 'min_samples_leaf': 3}
# Val C-Index: 0.6624002659574468
#
# [344/800] {'n_estimators': 71, 'max_depth': 2, 'min_samples_leaf': 4}
# Val C-Index: 0.6626662234042553
#
# [345/800] {'n_estimators': 71, 'max_depth': 3, 'min_samples_leaf': 1}
# Val C-Index: 0.6785738031914894
#
# [346/800] {'n_estimators': 71, 'max_depth': 3, 'min_samples_leaf': 2}
# Val C-Index: 0.6787234042553192
#
# [347/800] {'n_estimators': 71, 'max_depth': 3, 'min_samples_leaf': 3}
# Val C-Index: 0.6782579787234042
#
# [348/800] {'n_estimators': 71, 'max_depth': 3, 'min_samples_leaf': 4}
# Val C-Index: 0.6784906914893617
#
# [349/800] {'n_estimators': 71, 'max_depth': 4, 'min_samples_leaf': 1}
# Val C-Index: 0.6705784574468086
#
# [350/800] {'n_estimators': 71, 'max_depth': 4, 'min_samples_leaf': 2}
# Val C-Index: 0.6739029255319149
#
# [351/800] {'n_estimators': 71, 'max_depth': 4, 'min_samples_leaf': 3}
# Val C-Index: 0.6733876329787234
#
# [352/800] {'n_estimators': 71, 'max_depth': 4, 'min_samples_leaf': 4}
# Val C-Index: 0.6710106382978723
#
# [353/800] {'n_estimators': 72, 'max_depth': 1, 'min_samples_leaf': 1}
# Val C-Index: 0.6641456117021277
#
# [354/800] {'n_estimators': 72, 'max_depth': 1, 'min_samples_leaf': 2}
# Val C-Index: 0.6641456117021277
#
# [355/800] {'n_estimators': 72, 'max_depth': 1, 'min_samples_leaf': 3}
# Val C-Index: 0.6641456117021277
#
# [356/800] {'n_estimators': 72, 'max_depth': 1, 'min_samples_leaf': 4}
# Val C-Index: 0.6641456117021277
#
# [357/800] {'n_estimators': 72, 'max_depth': 2, 'min_samples_leaf': 1}
# Val C-Index: 0.6620678191489362
#
# [358/800] {'n_estimators': 72, 'max_depth': 2, 'min_samples_leaf': 2}
# Val C-Index: 0.6620678191489362
#
# [359/800] {'n_estimators': 72, 'max_depth': 2, 'min_samples_leaf': 3}
# Val C-Index: 0.6625831117021277
#
# [360/800] {'n_estimators': 72, 'max_depth': 2, 'min_samples_leaf': 4}
# Val C-Index: 0.6628823138297872
#
# [361/800] {'n_estimators': 72, 'max_depth': 3, 'min_samples_leaf': 1}
# Val C-Index: 0.6789561170212766
#
# [362/800] {'n_estimators': 72, 'max_depth': 3, 'min_samples_leaf': 2}
# Val C-Index: 0.67890625
#
# [363/800] {'n_estimators': 72, 'max_depth': 3, 'min_samples_leaf': 3}
# Val C-Index: 0.6784075797872341
#
# [364/800] {'n_estimators': 72, 'max_depth': 3, 'min_samples_leaf': 4}
# Val C-Index: 0.6784574468085106
#
# [365/800] {'n_estimators': 72, 'max_depth': 4, 'min_samples_leaf': 1}
# Val C-Index: 0.6715093085106383
#
# [366/800] {'n_estimators': 72, 'max_depth': 4, 'min_samples_leaf': 2}
# Val C-Index: 0.6744348404255319
#
# [367/800] {'n_estimators': 72, 'max_depth': 4, 'min_samples_leaf': 3}
# Val C-Index: 0.674002659574468
#
# [368/800] {'n_estimators': 72, 'max_depth': 4, 'min_samples_leaf': 4}
# Val C-Index: 0.672091090425532
#
# [369/800] {'n_estimators': 73, 'max_depth': 1, 'min_samples_leaf': 1}
# Val C-Index: 0.6620511968085107
#
# [370/800] {'n_estimators': 73, 'max_depth': 1, 'min_samples_leaf': 2}
# Val C-Index: 0.6620511968085107
#
# [371/800] {'n_estimators': 73, 'max_depth': 1, 'min_samples_leaf': 3}
# Val C-Index: 0.6620511968085107
#
# [372/800] {'n_estimators': 73, 'max_depth': 1, 'min_samples_leaf': 4}
# Val C-Index: 0.6620511968085107
#
# [373/800] {'n_estimators': 73, 'max_depth': 2, 'min_samples_leaf': 1}
# Val C-Index: 0.6616356382978723
#
# [374/800] {'n_estimators': 73, 'max_depth': 2, 'min_samples_leaf': 2}
# Val C-Index: 0.6616356382978723
#
# [375/800] {'n_estimators': 73, 'max_depth': 2, 'min_samples_leaf': 3}
# Val C-Index: 0.6620844414893617
#
# [376/800] {'n_estimators': 73, 'max_depth': 2, 'min_samples_leaf': 4}
# Val C-Index: 0.6623670212765957
#
# [377/800] {'n_estimators': 73, 'max_depth': 3, 'min_samples_leaf': 1}
# Val C-Index: 0.6779753989361702
#
# [378/800] {'n_estimators': 73, 'max_depth': 3, 'min_samples_leaf': 2}
# Val C-Index: 0.6777925531914893
#
# [379/800] {'n_estimators': 73, 'max_depth': 3, 'min_samples_leaf': 3}
# Val C-Index: 0.6776595744680851
#
# [380/800] {'n_estimators': 73, 'max_depth': 3, 'min_samples_leaf': 4}
# Val C-Index: 0.6777759308510638
#
# [381/800] {'n_estimators': 73, 'max_depth': 4, 'min_samples_leaf': 1}
# Val C-Index: 0.6696476063829787
#
# [382/800] {'n_estimators': 73, 'max_depth': 4, 'min_samples_leaf': 2}
# Val C-Index: 0.6723902925531915
#
# [383/800] {'n_estimators': 73, 'max_depth': 4, 'min_samples_leaf': 3}
# Val C-Index: 0.6739195478723404
#
# [384/800] {'n_estimators': 73, 'max_depth': 4, 'min_samples_leaf': 4}
# Val C-Index: 0.6720744680851064
#
# [385/800] {'n_estimators': 74, 'max_depth': 1, 'min_samples_leaf': 1}
# Val C-Index: 0.66171875
#
# [386/800] {'n_estimators': 74, 'max_depth': 1, 'min_samples_leaf': 2}
# Val C-Index: 0.66171875
#
# [387/800] {'n_estimators': 74, 'max_depth': 1, 'min_samples_leaf': 3}
# Val C-Index: 0.66171875
#
# [388/800] {'n_estimators': 74, 'max_depth': 1, 'min_samples_leaf': 4}
# Val C-Index: 0.66171875
#
# [389/800] {'n_estimators': 74, 'max_depth': 2, 'min_samples_leaf': 1}
# Val C-Index: 0.6614527925531914
#
# [390/800] {'n_estimators': 74, 'max_depth': 2, 'min_samples_leaf': 2}
# Val C-Index: 0.6614527925531914
#
# [391/800] {'n_estimators': 74, 'max_depth': 2, 'min_samples_leaf': 3}
# Val C-Index: 0.6618018617021276
#
# [392/800] {'n_estimators': 74, 'max_depth': 2, 'min_samples_leaf': 4}
# Val C-Index: 0.6621010638297873
#
# [393/800] {'n_estimators': 74, 'max_depth': 3, 'min_samples_leaf': 1}
# Val C-Index: 0.6774933510638298
#
# [394/800] {'n_estimators': 74, 'max_depth': 3, 'min_samples_leaf': 2}
# Val C-Index: 0.6772938829787234
#
# [395/800] {'n_estimators': 74, 'max_depth': 3, 'min_samples_leaf': 3}
# Val C-Index: 0.6776097074468085
#
# [396/800] {'n_estimators': 74, 'max_depth': 3, 'min_samples_leaf': 4}
# Val C-Index: 0.6775764627659574
#
# [397/800] {'n_estimators': 74, 'max_depth': 4, 'min_samples_leaf': 1}
# Val C-Index: 0.6705285904255319
#
# [398/800] {'n_estimators': 74, 'max_depth': 4, 'min_samples_leaf': 2}
# Val C-Index: 0.6735206117021276
#
# [399/800] {'n_estimators': 74, 'max_depth': 4, 'min_samples_leaf': 3}
# Val C-Index: 0.6744015957446808
#
# [400/800] {'n_estimators': 74, 'max_depth': 4, 'min_samples_leaf': 4}
# Val C-Index: 0.6727892287234043
#
# [401/800] {'n_estimators': 75, 'max_depth': 1, 'min_samples_leaf': 1}
# Val C-Index: 0.6620179521276596
# [402/800] {'n_estimators': 75, 'max_depth': 1, 'min_samples_leaf': 2}
# Val C-Index: 0.6620179521276596
#
# [403/800] {'n_estimators': 75, 'max_depth': 1, 'min_samples_leaf': 3}
# Val C-Index: 0.6620179521276596
#
# [404/800] {'n_estimators': 75, 'max_depth': 1, 'min_samples_leaf': 4}
# Val C-Index: 0.6620179521276596
#
# [405/800] {'n_estimators': 75, 'max_depth': 2, 'min_samples_leaf': 1}
# Val C-Index: 0.662217420212766
#
# [406/800] {'n_estimators': 75, 'max_depth': 2, 'min_samples_leaf': 2}
# Val C-Index: 0.662217420212766
#
# [407/800] {'n_estimators': 75, 'max_depth': 2, 'min_samples_leaf': 3}
# Val C-Index: 0.6626163563829788
#
# [408/800] {'n_estimators': 75, 'max_depth': 2, 'min_samples_leaf': 4}
# Val C-Index: 0.6628989361702128
#
# [409/800] {'n_estimators': 75, 'max_depth': 3, 'min_samples_leaf': 1}
# Val C-Index: 0.6774434840425532
#
# [410/800] {'n_estimators': 75, 'max_depth': 3, 'min_samples_leaf': 2}
# Val C-Index: 0.6775432180851064
#
# [411/800] {'n_estimators': 75, 'max_depth': 3, 'min_samples_leaf': 3}
# Val C-Index: 0.6776928191489362
#
# [412/800] {'n_estimators': 75, 'max_depth': 3, 'min_samples_leaf': 4}
# Val C-Index: 0.6775265957446809
#
# [413/800] {'n_estimators': 75, 'max_depth': 4, 'min_samples_leaf': 1}
# Val C-Index: 0.6708277925531915
#
# [414/800] {'n_estimators': 75, 'max_depth': 4, 'min_samples_leaf': 2}
# Val C-Index: 0.6738530585106383
#
# [415/800] {'n_estimators': 75, 'max_depth': 4, 'min_samples_leaf': 3}
# Val C-Index: 0.6745511968085106
#
# [416/800] {'n_estimators': 75, 'max_depth': 4, 'min_samples_leaf': 4}
# Val C-Index: 0.6731715425531914
#
# [417/800] {'n_estimators': 76, 'max_depth': 1, 'min_samples_leaf': 1}
# Val C-Index: 0.6607297207446808
#
# [418/800] {'n_estimators': 76, 'max_depth': 1, 'min_samples_leaf': 2}
# Val C-Index: 0.6607297207446808
#
# [419/800] {'n_estimators': 76, 'max_depth': 1, 'min_samples_leaf': 3}
# Val C-Index: 0.6607297207446808
#
# [420/800] {'n_estimators': 76, 'max_depth': 1, 'min_samples_leaf': 4}
# Val C-Index: 0.6607297207446808
#
# [421/800] {'n_estimators': 76, 'max_depth': 2, 'min_samples_leaf': 1}
# Val C-Index: 0.6625498670212766
#
# [422/800] {'n_estimators': 76, 'max_depth': 2, 'min_samples_leaf': 2}
# Val C-Index: 0.6625498670212766
#
# [423/800] {'n_estimators': 76, 'max_depth': 2, 'min_samples_leaf': 3}
# Val C-Index: 0.6629321808510639
#
# [424/800] {'n_estimators': 76, 'max_depth': 2, 'min_samples_leaf': 4}
# Val C-Index: 0.663248005319149
#
# [425/800] {'n_estimators': 76, 'max_depth': 3, 'min_samples_leaf': 1}
# Val C-Index: 0.678125
#
# [426/800] {'n_estimators': 76, 'max_depth': 3, 'min_samples_leaf': 2}
# Val C-Index: 0.6780917553191489
#
# [427/800] {'n_estimators': 76, 'max_depth': 3, 'min_samples_leaf': 3}
# Val C-Index: 0.6778756648936171
#
# [428/800] {'n_estimators': 76, 'max_depth': 3, 'min_samples_leaf': 4}
# Val C-Index: 0.6775432180851064
#
# [429/800] {'n_estimators': 76, 'max_depth': 4, 'min_samples_leaf': 1}
# Val C-Index: 0.668999335106383
#
# [430/800] {'n_estimators': 76, 'max_depth': 4, 'min_samples_leaf': 2}
# Val C-Index: 0.6730884308510638
#
# [431/800] {'n_estimators': 76, 'max_depth': 4, 'min_samples_leaf': 3}
# Val C-Index: 0.6732712765957447
#
# [432/800] {'n_estimators': 76, 'max_depth': 4, 'min_samples_leaf': 4}
# Val C-Index: 0.6721077127659575
#
# [433/800] {'n_estimators': 77, 'max_depth': 1, 'min_samples_leaf': 1}
# Val C-Index: 0.6603806515957447
#
# [434/800] {'n_estimators': 77, 'max_depth': 1, 'min_samples_leaf': 2}
# Val C-Index: 0.6603806515957447
#
# [435/800] {'n_estimators': 77, 'max_depth': 1, 'min_samples_leaf': 3}
# Val C-Index: 0.6603806515957447
#
# [436/800] {'n_estimators': 77, 'max_depth': 1, 'min_samples_leaf': 4}
# Val C-Index: 0.6603806515957447
#
# [437/800] {'n_estimators': 77, 'max_depth': 2, 'min_samples_leaf': 1}
# Val C-Index: 0.6627160904255319
#
# [438/800] {'n_estimators': 77, 'max_depth': 2, 'min_samples_leaf': 2}
# Val C-Index: 0.6627160904255319
#
# [439/800] {'n_estimators': 77, 'max_depth': 2, 'min_samples_leaf': 3}
# Val C-Index: 0.6630651595744681
#
# [440/800] {'n_estimators': 77, 'max_depth': 2, 'min_samples_leaf': 4}
# Val C-Index: 0.6633643617021276
#
# [441/800] {'n_estimators': 77, 'max_depth': 3, 'min_samples_leaf': 1}
# Val C-Index: 0.6782579787234042
#
# [442/800] {'n_estimators': 77, 'max_depth': 3, 'min_samples_leaf': 2}
# Val C-Index: 0.6782912234042553
#
# [443/800] {'n_estimators': 77, 'max_depth': 3, 'min_samples_leaf': 3}
# Val C-Index: 0.6779421542553191
#
# [444/800] {'n_estimators': 77, 'max_depth': 3, 'min_samples_leaf': 4}
# Val C-Index: 0.6770113031914894
#
# [445/800] {'n_estimators': 77, 'max_depth': 4, 'min_samples_leaf': 1}
# Val C-Index: 0.6690325797872341
#
# [446/800] {'n_estimators': 77, 'max_depth': 4, 'min_samples_leaf': 2}
# Val C-Index: 0.6722905585106383
#
# [447/800] {'n_estimators': 77, 'max_depth': 4, 'min_samples_leaf': 3}
# Val C-Index: 0.6729720744680852
#
# [448/800] {'n_estimators': 77, 'max_depth': 4, 'min_samples_leaf': 4}
# Val C-Index: 0.6723071808510638
#
# [449/800] {'n_estimators': 78, 'max_depth': 1, 'min_samples_leaf': 1}
# Val C-Index: 0.6614943484042554
#
# [450/800] {'n_estimators': 78, 'max_depth': 1, 'min_samples_leaf': 2}
# Val C-Index: 0.6614943484042554
#
# [451/800] {'n_estimators': 78, 'max_depth': 1, 'min_samples_leaf': 3}
# Val C-Index: 0.6614943484042554
#
# [452/800] {'n_estimators': 78, 'max_depth': 1, 'min_samples_leaf': 4}
# Val C-Index: 0.6614943484042554
#
# [453/800] {'n_estimators': 78, 'max_depth': 2, 'min_samples_leaf': 1}
# Val C-Index: 0.6631815159574468
#
# [454/800] {'n_estimators': 78, 'max_depth': 2, 'min_samples_leaf': 2}
# Val C-Index: 0.6631815159574468
#
# [455/800] {'n_estimators': 78, 'max_depth': 2, 'min_samples_leaf': 3}
# Val C-Index: 0.6637632978723405
#
# [456/800] {'n_estimators': 78, 'max_depth': 2, 'min_samples_leaf': 4}
# Val C-Index: 0.6640458776595745
#
# [457/800] {'n_estimators': 78, 'max_depth': 3, 'min_samples_leaf': 1}
# Val C-Index: 0.6790890957446809
#
# [458/800] {'n_estimators': 78, 'max_depth': 3, 'min_samples_leaf': 2}
# Val C-Index: 0.6791057180851063
#
# [459/800] {'n_estimators': 78, 'max_depth': 3, 'min_samples_leaf': 3}
# Val C-Index: 0.6781083776595744
#
# [460/800] {'n_estimators': 78, 'max_depth': 3, 'min_samples_leaf': 4}
# Val C-Index: 0.6779587765957447
#
# [461/800] {'n_estimators': 78, 'max_depth': 4, 'min_samples_leaf': 1}
# Val C-Index: 0.668716755319149
#
# [462/800] {'n_estimators': 78, 'max_depth': 4, 'min_samples_leaf': 2}
# Val C-Index: 0.6724401595744681
#
# [463/800] {'n_estimators': 78, 'max_depth': 4, 'min_samples_leaf': 3}
# Val C-Index: 0.6726396276595744
#
# [464/800] {'n_estimators': 78, 'max_depth': 4, 'min_samples_leaf': 4}
# Val C-Index: 0.672406914893617
#
# [465/800] {'n_estimators': 79, 'max_depth': 1, 'min_samples_leaf': 1}
# Val C-Index: 0.6617270611702127
#
# [466/800] {'n_estimators': 79, 'max_depth': 1, 'min_samples_leaf': 2}
# Val C-Index: 0.6617270611702127
#
# [467/800] {'n_estimators': 79, 'max_depth': 1, 'min_samples_leaf': 3}
# Val C-Index: 0.6617270611702127
#
# [468/800] {'n_estimators': 79, 'max_depth': 1, 'min_samples_leaf': 4}
# Val C-Index: 0.6617270611702127
#
# ...
# [647/800] {'n_estimators': 90, 'max_depth': 2, 'min_samples_leaf': 3}
# Val C-Index: 0.6640292553191489
#
# [648/800] {'n_estimators': 90, 'max_depth': 2, 'min_samples_leaf': 4}
# Val C-Index: 0.6642121010638298
#
# [649/800] {'n_estimators': 90, 'max_depth': 3, 'min_samples_leaf': 1}
# Val C-Index: 0.6774102393617021
#
# [650/800] {'n_estimators': 90, 'max_depth': 3, 'min_samples_leaf': 2}
# Val C-Index: 0.6776595744680851
#
# [651/800] {'n_estimators': 90, 'max_depth': 3, 'min_samples_leaf': 3}
# Val C-Index: 0.6772606382978723
#
# [652/800] {'n_estimators': 90, 'max_depth': 3, 'min_samples_leaf': 4}
# Val C-Index: 0.6778756648936171
#
# [653/800] {'n_estimators': 90, 'max_depth': 4, 'min_samples_leaf': 1}
# Val C-Index: 0.6685671542553191
#
# [654/800] {'n_estimators': 90, 'max_depth': 4, 'min_samples_leaf': 2}
# Val C-Index: 0.67109375
#
# [655/800] {'n_estimators': 90, 'max_depth': 4, 'min_samples_leaf': 3}
# Val C-Index: 0.6729388297872341
#
# [656/800] {'n_estimators': 90, 'max_depth': 4, 'min_samples_leaf': 4}
# Val C-Index: 0.6726396276595744
#
# [657/800] {'n_estimators': 91, 'max_depth': 1, 'min_samples_leaf': 1}
# Val C-Index: 0.6556765292553192
#
# [658/800] {'n_estimators': 91, 'max_depth': 1, 'min_samples_leaf': 2}
# Val C-Index: 0.6556765292553192
#
# [659/800] {'n_estimators': 91, 'max_depth': 1, 'min_samples_leaf': 3}
# Val C-Index: 0.6556765292553192
#
# [660/800] {'n_estimators': 91, 'max_depth': 1, 'min_samples_leaf': 4}
# Val C-Index: 0.6556765292553192
#
# [661/800] {'n_estimators': 91, 'max_depth': 2, 'min_samples_leaf': 1}
# Val C-Index: 0.6630651595744681
#
# [662/800] {'n_estimators': 91, 'max_depth': 2, 'min_samples_leaf': 2}
# Val C-Index: 0.6630651595744681
#
# [663/800] {'n_estimators': 91, 'max_depth': 2, 'min_samples_leaf': 3}
# Val C-Index: 0.6636635638297872
#
# [664/800] {'n_estimators': 91, 'max_depth': 2, 'min_samples_leaf': 4}
# Val C-Index: 0.6637466755319149
#
# [665/800] {'n_estimators': 91, 'max_depth': 3, 'min_samples_leaf': 1}
# Val C-Index: 0.6769946808510638
#
# [666/800] {'n_estimators': 91, 'max_depth': 3, 'min_samples_leaf': 2}
# Val C-Index: 0.6771442819148936
#
# [667/800] {'n_estimators': 91, 'max_depth': 3, 'min_samples_leaf': 3}
# Val C-Index: 0.6765791223404255
#
# [668/800] {'n_estimators': 91, 'max_depth': 3, 'min_samples_leaf': 4}
# Val C-Index: 0.6774102393617021
#
# [669/800] {'n_estimators': 91, 'max_depth': 4, 'min_samples_leaf': 1}
# Val C-Index: 0.668251329787234
#
# [670/800] {'n_estimators': 91, 'max_depth': 4, 'min_samples_leaf': 2}
# Val C-Index: 0.6705119680851064
#
# [671/800] {'n_estimators': 91, 'max_depth': 4, 'min_samples_leaf': 3}
# Val C-Index: 0.6720246010638298
#
# [672/800] {'n_estimators': 91, 'max_depth': 4, 'min_samples_leaf': 4}
# Val C-Index: 0.6716422872340425
#
# [673/800] {'n_estimators': 92, 'max_depth': 1, 'min_samples_leaf': 1}
# Val C-Index: 0.6555435505319149
#
# [674/800] {'n_estimators': 92, 'max_depth': 1, 'min_samples_leaf': 2}
# Val C-Index: 0.6555435505319149
#
# [675/800] {'n_estimators': 92, 'max_depth': 1, 'min_samples_leaf': 3}
# Val C-Index: 0.6555435505319149
#
# [676/800] {'n_estimators': 92, 'max_depth': 1, 'min_samples_leaf': 4}
# Val C-Index: 0.6555435505319149
#
# [677/800] {'n_estimators': 92, 'max_depth': 2, 'min_samples_leaf': 1}
# Val C-Index: 0.6624002659574468
#
# [678/800] {'n_estimators': 92, 'max_depth': 2, 'min_samples_leaf': 2}
# Val C-Index: 0.6624002659574468
#
# [679/800] {'n_estimators': 92, 'max_depth': 2, 'min_samples_leaf': 3}
# Val C-Index: 0.6626828457446808
#
# [680/800] {'n_estimators': 92, 'max_depth': 2, 'min_samples_leaf': 4}
# Val C-Index: 0.6627659574468086
#
# [681/800] {'n_estimators': 92, 'max_depth': 3, 'min_samples_leaf': 1}
# Val C-Index: 0.6772772606382979
#
# [682/800] {'n_estimators': 92, 'max_depth': 3, 'min_samples_leaf': 2}
# Val C-Index: 0.6772107712765958
#
# [683/800] {'n_estimators': 92, 'max_depth': 3, 'min_samples_leaf': 3}
# Val C-Index: 0.6766954787234043
#
# [684/800] {'n_estimators': 92, 'max_depth': 3, 'min_samples_leaf': 4}
# Val C-Index: 0.6766123670212766
#
# [685/800] {'n_estimators': 92, 'max_depth': 4, 'min_samples_leaf': 1}
# Val C-Index: 0.6683178191489362
#
# [686/800] {'n_estimators': 92, 'max_depth': 4, 'min_samples_leaf': 2}
# Val C-Index: 0.6708111702127659
#
# [687/800] {'n_estimators': 92, 'max_depth': 4, 'min_samples_leaf': 3}
# Val C-Index: 0.6721908244680851
#
# [688/800] {'n_estimators': 92, 'max_depth': 4, 'min_samples_leaf': 4}
# Val C-Index: 0.6727726063829788
#
# [689/800] {'n_estimators': 93, 'max_depth': 1, 'min_samples_leaf': 1}
# Val C-Index: 0.6556432845744681
#
# [690/800] {'n_estimators': 93, 'max_depth': 1, 'min_samples_leaf': 2}
# Val C-Index: 0.6556432845744681
#
# [691/800] {'n_estimators': 93, 'max_depth': 1, 'min_samples_leaf': 3}
# Val C-Index: 0.6556432845744681
#
# [692/800] {'n_estimators': 93, 'max_depth': 1, 'min_samples_leaf': 4}
# Val C-Index: 0.6556432845744681
#
# [693/800] {'n_estimators': 93, 'max_depth': 2, 'min_samples_leaf': 1}
# Val C-Index: 0.6628823138297872
#
# [694/800] {'n_estimators': 93, 'max_depth': 2, 'min_samples_leaf': 2}
# Val C-Index: 0.6628823138297872
#
# [695/800] {'n_estimators': 93, 'max_depth': 2, 'min_samples_leaf': 3}
# Val C-Index: 0.6630485372340426
#
# [696/800] {'n_estimators': 93, 'max_depth': 2, 'min_samples_leaf': 4}
# Val C-Index: 0.6631482712765957
#
# [697/800] {'n_estimators': 93, 'max_depth': 3, 'min_samples_leaf': 1}
# Val C-Index: 0.6777925531914893
#
# [698/800] {'n_estimators': 93, 'max_depth': 3, 'min_samples_leaf': 2}
# Val C-Index: 0.6775764627659574
#
# [699/800] {'n_estimators': 93, 'max_depth': 3, 'min_samples_leaf': 3}
# Val C-Index: 0.6769614361702128
#
# [700/800] {'n_estimators': 93, 'max_depth': 3, 'min_samples_leaf': 4}
# Val C-Index: 0.6775099734042553
#
# [701/800] {'n_estimators': 93, 'max_depth': 4, 'min_samples_leaf': 1}
# Val C-Index: 0.6698803191489362
#
# [702/800] {'n_estimators': 93, 'max_depth': 4, 'min_samples_leaf': 2}
# Val C-Index: 0.6725731382978724
#
# [703/800] {'n_estimators': 93, 'max_depth': 4, 'min_samples_leaf': 3}
# Val C-Index: 0.6731549202127659
#
# [704/800] {'n_estimators': 93, 'max_depth': 4, 'min_samples_leaf': 4}
# Val C-Index: 0.6733543882978723
#
# [705/800] {'n_estimators': 94, 'max_depth': 1, 'min_samples_leaf': 1}
# Val C-Index: 0.6572057845744681
#
# [706/800] {'n_estimators': 94, 'max_depth': 1, 'min_samples_leaf': 2}
# Val C-Index: 0.6572057845744681
#
# [707/800] {'n_estimators': 94, 'max_depth': 1, 'min_samples_leaf': 3}
# Val C-Index: 0.6572057845744681
#
# [708/800] {'n_estimators': 94, 'max_depth': 1, 'min_samples_leaf': 4}
# Val C-Index: 0.6572057845744681
#
# [709/800] {'n_estimators': 94, 'max_depth': 2, 'min_samples_leaf': 1}
# Val C-Index: 0.663031914893617
#
# [710/800] {'n_estimators': 94, 'max_depth': 2, 'min_samples_leaf': 2}
# Val C-Index: 0.663031914893617
#
# [711/800] {'n_estimators': 94, 'max_depth': 2, 'min_samples_leaf': 3}
# Val C-Index: 0.6634474734042554
#
# [712/800] {'n_estimators': 94, 'max_depth': 2, 'min_samples_leaf': 4}
# Val C-Index: 0.6635970744680851
#
# [713/800] {'n_estimators': 94, 'max_depth': 3, 'min_samples_leaf': 1}
# Val C-Index: 0.6792054521276596
#
# [714/800] {'n_estimators': 94, 'max_depth': 3, 'min_samples_leaf': 2}
# Val C-Index: 0.6791389627659574
#
# [715/800] {'n_estimators': 94, 'max_depth': 3, 'min_samples_leaf': 3}
# Val C-Index: 0.6781416223404255
#
# [716/800] {'n_estimators': 94, 'max_depth': 3, 'min_samples_leaf': 4}
# Val C-Index: 0.6784906914893617
#
# [717/800] {'n_estimators': 94, 'max_depth': 4, 'min_samples_leaf': 1}
# Val C-Index: 0.6696808510638298
#
# [718/800] {'n_estimators': 94, 'max_depth': 4, 'min_samples_leaf': 2}
# Val C-Index: 0.672124335106383
#
# [719/800] {'n_estimators': 94, 'max_depth': 4, 'min_samples_leaf': 3}
# Val C-Index: 0.6730219414893617
#
# [720/800] {'n_estimators': 94, 'max_depth': 4, 'min_samples_leaf': 4}
# Val C-Index: 0.6736203457446809
#
# [721/800] {'n_estimators': 95, 'max_depth': 1, 'min_samples_leaf': 1}
# Val C-Index: 0.6561087101063829
# [722/800] {'n_estimators': 95, 'max_depth': 1, 'min_samples_leaf': 2}
# Val C-Index: 0.6561087101063829
#
# [723/800] {'n_estimators': 95, 'max_depth': 1, 'min_samples_leaf': 3}
# Val C-Index: 0.6561087101063829
#
# [724/800] {'n_estimators': 95, 'max_depth': 1, 'min_samples_leaf': 4}
# Val C-Index: 0.6561087101063829
#
# [725/800] {'n_estimators': 95, 'max_depth': 2, 'min_samples_leaf': 1}
# Val C-Index: 0.6624002659574468
#
# [726/800] {'n_estimators': 95, 'max_depth': 2, 'min_samples_leaf': 2}
# Val C-Index: 0.6624002659574468
#
# [727/800] {'n_estimators': 95, 'max_depth': 2, 'min_samples_leaf': 3}
# Val C-Index: 0.6627327127659575
#
# [728/800] {'n_estimators': 95, 'max_depth': 2, 'min_samples_leaf': 4}
# Val C-Index: 0.6628656914893617
#
# [729/800] {'n_estimators': 95, 'max_depth': 3, 'min_samples_leaf': 1}
# Val C-Index: 0.6782746010638298
#
# [730/800] {'n_estimators': 95, 'max_depth': 3, 'min_samples_leaf': 2}
# Val C-Index: 0.6780252659574468
#
# [731/800] {'n_estimators': 95, 'max_depth': 3, 'min_samples_leaf': 3}
# Val C-Index: 0.6776429521276596
#
# [732/800] {'n_estimators': 95, 'max_depth': 3, 'min_samples_leaf': 4}
# Val C-Index: 0.677559840425532
#
# [733/800] {'n_estimators': 95, 'max_depth': 4, 'min_samples_leaf': 1}
# Val C-Index: 0.6688164893617021
#
# [734/800] {'n_estimators': 95, 'max_depth': 4, 'min_samples_leaf': 2}
# Val C-Index: 0.671343085106383
#
# [735/800] {'n_estimators': 95, 'max_depth': 4, 'min_samples_leaf': 3}
# Val C-Index: 0.6729554521276596
#
# [736/800] {'n_estimators': 95, 'max_depth': 4, 'min_samples_leaf': 4}
# Val C-Index: 0.6729886968085106
#
# [737/800] {'n_estimators': 96, 'max_depth': 1, 'min_samples_leaf': 1}
# Val C-Index: 0.6565741356382979
#
# [738/800] {'n_estimators': 96, 'max_depth': 1, 'min_samples_leaf': 2}
# Val C-Index: 0.6565741356382979
#
# [739/800] {'n_estimators': 96, 'max_depth': 1, 'min_samples_leaf': 3}
# Val C-Index: 0.6565741356382979
#
# [740/800] {'n_estimators': 96, 'max_depth': 1, 'min_samples_leaf': 4}
# Val C-Index: 0.6565741356382979
#
# [741/800] {'n_estimators': 96, 'max_depth': 2, 'min_samples_leaf': 1}
# Val C-Index: 0.6630984042553192
#
# [742/800] {'n_estimators': 96, 'max_depth': 2, 'min_samples_leaf': 2}
# Val C-Index: 0.6630984042553192
#
# [743/800] {'n_estimators': 96, 'max_depth': 2, 'min_samples_leaf': 3}
# Val C-Index: 0.6635804521276596
#
# [744/800] {'n_estimators': 96, 'max_depth': 2, 'min_samples_leaf': 4}
# Val C-Index: 0.6636303191489362
#
# [745/800] {'n_estimators': 96, 'max_depth': 3, 'min_samples_leaf': 1}
# Val C-Index: 0.6776097074468085
#
# [746/800] {'n_estimators': 96, 'max_depth': 3, 'min_samples_leaf': 2}
# Val C-Index: 0.6775099734042553
#
# [747/800] {'n_estimators': 96, 'max_depth': 3, 'min_samples_leaf': 3}
# Val C-Index: 0.6769780585106383
#
# [748/800] {'n_estimators': 96, 'max_depth': 3, 'min_samples_leaf': 4}
# Val C-Index: 0.6769448138297872
#
# [749/800] {'n_estimators': 96, 'max_depth': 4, 'min_samples_leaf': 1}
# Val C-Index: 0.6688331117021277
#
# [750/800] {'n_estimators': 96, 'max_depth': 4, 'min_samples_leaf': 2}
# Val C-Index: 0.6704454787234042
#
# [751/800] {'n_estimators': 96, 'max_depth': 4, 'min_samples_leaf': 3}
# Val C-Index: 0.6716755319148936
#
# [752/800] {'n_estimators': 96, 'max_depth': 4, 'min_samples_leaf': 4}
# Val C-Index: 0.6720412234042553
#
# [753/800] {'n_estimators': 97, 'max_depth': 1, 'min_samples_leaf': 1}
# Val C-Index: 0.6566572473404255
#
# [754/800] {'n_estimators': 97, 'max_depth': 1, 'min_samples_leaf': 2}
# Val C-Index: 0.6566572473404255
#
# [755/800] {'n_estimators': 97, 'max_depth': 1, 'min_samples_leaf': 3}
# Val C-Index: 0.6566572473404255
#
# [756/800] {'n_estimators': 97, 'max_depth': 1, 'min_samples_leaf': 4}
# Val C-Index: 0.6566572473404255
#
# [757/800] {'n_estimators': 97, 'max_depth': 2, 'min_samples_leaf': 1}
# Val C-Index: 0.6631150265957447
#
# [758/800] {'n_estimators': 97, 'max_depth': 2, 'min_samples_leaf': 2}
# Val C-Index: 0.6631150265957447
#
# [759/800] {'n_estimators': 97, 'max_depth': 2, 'min_samples_leaf': 3}
# Val C-Index: 0.663530585106383
#
# [760/800] {'n_estimators': 97, 'max_depth': 2, 'min_samples_leaf': 4}
# Val C-Index: 0.6636635638297872
#
# [761/800] {'n_estimators': 97, 'max_depth': 3, 'min_samples_leaf': 1}
# Val C-Index: 0.6770279255319149
#
# [762/800] {'n_estimators': 97, 'max_depth': 3, 'min_samples_leaf': 2}
# Val C-Index: 0.6769614361702128
#
# [763/800] {'n_estimators': 97, 'max_depth': 3, 'min_samples_leaf': 3}
# Val C-Index: 0.6765625
#
# [764/800] {'n_estimators': 97, 'max_depth': 3, 'min_samples_leaf': 4}
# Val C-Index: 0.6768284574468085
#
# [765/800] {'n_estimators': 97, 'max_depth': 4, 'min_samples_leaf': 1}
# Val C-Index: 0.668467420212766
#
# [766/800] {'n_estimators': 97, 'max_depth': 4, 'min_samples_leaf': 2}
# Val C-Index: 0.6693816489361702
#
# [767/800] {'n_estimators': 97, 'max_depth': 4, 'min_samples_leaf': 3}
# Val C-Index: 0.671060505319149
#
# [768/800] {'n_estimators': 97, 'max_depth': 4, 'min_samples_leaf': 4}
# Val C-Index: 0.6729720744680852
#
# [769/800] {'n_estimators': 98, 'max_depth': 1, 'min_samples_leaf': 1}
# Val C-Index: 0.6563912898936171
#
# [770/800] {'n_estimators': 98, 'max_depth': 1, 'min_samples_leaf': 2}
# Val C-Index: 0.6563912898936171
#
# [771/800] {'n_estimators': 98, 'max_depth': 1, 'min_samples_leaf': 3}
# Val C-Index: 0.6563912898936171
#
# [772/800] {'n_estimators': 98, 'max_depth': 1, 'min_samples_leaf': 4}
# Val C-Index: 0.6563912898936171
#
# [773/800] {'n_estimators': 98, 'max_depth': 2, 'min_samples_leaf': 1}
# Val C-Index: 0.6628989361702128
#
# [774/800] {'n_estimators': 98, 'max_depth': 2, 'min_samples_leaf': 2}
# Val C-Index: 0.6628989361702128
#
# [775/800] {'n_estimators': 98, 'max_depth': 2, 'min_samples_leaf': 3}
# Val C-Index: 0.6632646276595745
#
# [776/800] {'n_estimators': 98, 'max_depth': 2, 'min_samples_leaf': 4}
# Val C-Index: 0.6634640957446809
#
# [777/800] {'n_estimators': 98, 'max_depth': 3, 'min_samples_leaf': 1}
# Val C-Index: 0.6777925531914893
#
# [778/800] {'n_estimators': 98, 'max_depth': 3, 'min_samples_leaf': 2}
# Val C-Index: 0.6776097074468085
#
# [779/800] {'n_estimators': 98, 'max_depth': 3, 'min_samples_leaf': 3}
# Val C-Index: 0.6769448138297872
#
# [780/800] {'n_estimators': 98, 'max_depth': 3, 'min_samples_leaf': 4}
# Val C-Index: 0.6767619680851064
#
# [781/800] {'n_estimators': 98, 'max_depth': 4, 'min_samples_leaf': 1}
# Val C-Index: 0.668999335106383
#
# [782/800] {'n_estimators': 98, 'max_depth': 4, 'min_samples_leaf': 2}
# Val C-Index: 0.6693484042553192
#
# [783/800] {'n_estimators': 98, 'max_depth': 4, 'min_samples_leaf': 3}
# Val C-Index: 0.6719581117021277
#
# [784/800] {'n_estimators': 98, 'max_depth': 4, 'min_samples_leaf': 4}
# Val C-Index: 0.6737533244680851
#
# [785/800] {'n_estimators': 99, 'max_depth': 1, 'min_samples_leaf': 1}
# Val C-Index: 0.6559092420212767
#
# [786/800] {'n_estimators': 99, 'max_depth': 1, 'min_samples_leaf': 2}
# Val C-Index: 0.6559092420212767
#
# [787/800] {'n_estimators': 99, 'max_depth': 1, 'min_samples_leaf': 3}
# Val C-Index: 0.6559092420212767
#
# [788/800] {'n_estimators': 99, 'max_depth': 1, 'min_samples_leaf': 4}
# Val C-Index: 0.6559092420212767
#
# [789/800] {'n_estimators': 99, 'max_depth': 2, 'min_samples_leaf': 1}
# Val C-Index: 0.6629654255319148
#
# [790/800] {'n_estimators': 99, 'max_depth': 2, 'min_samples_leaf': 2}
# Val C-Index: 0.6629654255319148
#
# [791/800] {'n_estimators': 99, 'max_depth': 2, 'min_samples_leaf': 3}
# Val C-Index: 0.6631316489361702
#
# [792/800] {'n_estimators': 99, 'max_depth': 2, 'min_samples_leaf': 4}
# Val C-Index: 0.663248005319149
#
# [793/800] {'n_estimators': 99, 'max_depth': 3, 'min_samples_leaf': 1}
# Val C-Index: 0.6787067819148936
#
# [794/800] {'n_estimators': 99, 'max_depth': 3, 'min_samples_leaf': 2}
# Val C-Index: 0.6783909574468086
#
# [795/800] {'n_estimators': 99, 'max_depth': 3, 'min_samples_leaf': 3}
# Val C-Index: 0.6776429521276596
#
# [796/800] {'n_estimators': 99, 'max_depth': 3, 'min_samples_leaf': 4}
# Val C-Index: 0.6773769946808511
#
# [797/800] {'n_estimators': 99, 'max_depth': 4, 'min_samples_leaf': 1}
# Val C-Index: 0.6682347074468085
#
# [798/800] {'n_estimators': 99, 'max_depth': 4, 'min_samples_leaf': 2}
# Val C-Index: 0.668467420212766
#
# [799/800] {'n_estimators': 99, 'max_depth': 4, 'min_samples_leaf': 3}
# Val C-Index: 0.6705285904255319
#
# [800/800] {'n_estimators': 99, 'max_depth': 4, 'min_samples_leaf': 4}
# Val C-Index: 0.6727227393617021
#
# Best hyperparameters:
# {'n_estimators': 85, 'max_depth': 3, 'min_samples_leaf': 2, 'random_state': 10}
# Train C-Index: 0.7712621719373087
# Val C-Index: 0.6806017287234043

# %% [markdown]
# Finally, evaluate the model on the test set. This is a crucial step, as trying out many combinations of hyperparameters and evaluating them on the validation set could result in a model that ends up overfitting the validation set. We therefore need to check if the model performs well on unseen data, which is the role of the test set, which we have held out until now.

# %%
# UNQ_C3 (UNIQUE CELL IDENTIFIER, DO NOT EDIT)
y_test_best = best_rf.predict_proba(X_test)[:, 1]

print(f"Test C-Index: {cindex(y_test.values, y_test_best)}")
# Out:
# Test C-Index: 0.6993734441584744

# %% [markdown]
# Your C-Index on the test set should be greater than `0.6`.

# %% [markdown]
# <a name='7'></a>
# ## 7. Imputation
#
# You've now built and optimized a random forest model on our data. However, there was still a drop in test C-Index. This might be because you threw away more than half of the data of our data because of missing values for systolic blood pressure. Instead, we can try filling in, or imputing, these values.
#
# First, let's explore to see if our data is missing at random or not. Let's plot histograms of the dropped rows against each of the covariates (aside from systolic blood pressure) to see if there is a trend. Compare these to the histograms of the feature in the entire dataset. Try to see if one of the covariates has a signficantly different distribution in the two subsets.

# %%
dropped_rows = X_train[X_train.isnull().any(axis=1)]

columns_except_Systolic_BP = [col for col in X_train.columns if col not in ['Systolic BP']]

for col in columns_except_Systolic_BP:
    sns.distplot(X_train.loc[:, col], norm_hist=True, kde=False, label='full data')
    sns.distplot(dropped_rows.loc[:, col], norm_hist=True, kde=False, label='without missing data')
    plt.legend()

    plt.show()

# %% [markdown]
# Most of the covariates are distributed similarly whether or not we have discarded rows with missing data. In other words missingness of the data is independent of these covariates.
#
# If this had been true across *all* covariates, then the data would have been said to be **missing completely at random (MCAR)**.
#
# But when considering the age covariate, we see that much more data tends to be missing for patients over 65. The reason could be that blood pressure was measured less frequently for old people to avoid placing additional burden on them.
#
# As missingness is related to one or more covariates, the missing data is said to be **missing at random (MAR)**.
#
# Based on the information we have, there is however no reason to believe that the _values_ of the missing data — or specifically the values of the missing systolic blood pressures — are related to the age of the patients.
# If this was the case, then this data would be said to be **missing not at random (MNAR)**.

# %% [markdown]
# <a name='8'></a>
# ## 8. Error Analysis
#
# <a name='Ex-4'></a>
# ### Exercise 4
# Using the information from the plots above, try to find a subgroup of the test data on which the model performs poorly. You should be able to easily find a subgroup of at least 250 cases on which the model has a C-Index of less than 0.69.

# %% [markdown]
# <details>
# <summary>
#     <font size="3" color="darkgreen"><b>Hints</b></font>
# </summary>
# <p>
# <ul>
#     <li> Define a mask using a feature and a threshold, e.g. patients with a BMI below 20: <code>mask = X_test['BMI'] < 20 </code>. </li>
#     <li> Try to find a subgroup for which the model had little data.</li>
# </ul>
# </p>

# %%
# UNQ_C4 (UNIQUE CELL IDENTIFIER, DO NOT EDIT)
def bad_subset(forest, X_test, y_test):
    # define mask to select large subset with poor performance
    # currently mask defines the entire set
    
    ### START CODE HERE (REPLACE the code after 'mask =' with your code) ###
    mask = X_test.Age>=68
    ### END CODE HERE ###

    X_subgroup = X_test[mask]
    y_subgroup = y_test[mask]
    subgroup_size = len(X_subgroup)

    y_subgroup_preds = forest.predict_proba(X_subgroup)[:, 1]
    performance = cindex(y_subgroup.values, y_subgroup_preds)
    
    return performance, subgroup_size

# %% [markdown]
# #### Test Your Work

# %%
performance, subgroup_size = bad_subset(best_rf, X_test, y_test)
print("Subgroup size should greater than 250, performance should be less than 0.69 ")
print(f"Subgroup size: {subgroup_size}, C-Index: {performance}")
# Out:
# Subgroup size should greater than 250, performance should be less than 0.69
# Subgroup size: 320, C-Index: 0.6663914120561519

# %% [markdown]
# #### Expected Output
# Note, your actual output will vary depending on the hyper-parameters that you chose and the mask that you chose.
# - Make sure that the c-index is less than 0.69
# ```Python
# Subgroup size: 586, C-Index: 0.6275
# ```
#
# **Bonus**:
# - See if you can get a c-index as low as 0.53
# ```
# Subgroup size: 251, C-Index: 0.5331
# ```

# %% [markdown]
# <a name='9'></a>
# ## 9. Imputation Approaches
#
# Seeing that our data is not missing completely at random, we can handle the missing values by replacing them with substituted values based on the other values that we have. This is known as imputation.
#
# The first imputation strategy that we will use is **mean substitution**: we will replace the missing values for each feature with the mean of the available values. In the next cell, use the `SimpleImputer` from `sklearn` to use mean imputation for the missing values.

# %%
# Impute values using the mean
imputer = SimpleImputer(strategy='mean')
imputer.fit(X_train)
X_train_mean_imputed = pd.DataFrame(imputer.transform(X_train), columns=X_train.columns)
X_val_mean_imputed = pd.DataFrame(imputer.transform(X_val), columns=X_val.columns)

# %% [markdown]
# <a name='Ex-5'></a>
# ### Exercise 5
# Now perform a hyperparameter grid search to find the best-performing random forest model, and report results on the test set.
#
# Define the parameter ranges for the hyperparameter search in the next cell, and run the cell.
#
# #### Target performance
# Make your test c-index at least 0.74 or higher

# %% [markdown]
# <details>
# <summary>
#     <font size="3" color="darkgreen"><b>Hints</b></font>
# </summary>
# <p>
# <ul>
#     <li>n_estimators: try values greater than 100</li>
#     <li>max_depth: try values in the range 1 to 100</li>
#     <li>min_samples_leaf: try float values below .5 and/or int values greater than 2</li>
# </ul>
# </p>

# %%
# Define ranges for the random forest hyperparameter search 
hyperparams = {
    ### START CODE HERE (REPLACE array values with your code) ###

    # how many trees should be in the forest (int)
    'n_estimators': range(100,120),

    # the maximum depth of trees in the forest (int)
    'max_depth': [1,2,3,4],

    # the minimum number of samples in a leaf as a fraction
    # of the total number of samples in the training set
    # Can be int (in which case that is the minimum number)
    # or float (in which case the minimum is that fraction of the
    # number of training set samples)
    'min_samples_leaf': [1,2,3],

    ### END CODE HERE ###
}

# %%
# UNQ_C5 (UNIQUE CELL IDENTIFIER, DO NOT EDIT)
rf = RandomForestClassifier

rf_mean_imputed, best_hyperparams_mean_imputed = holdout_grid_search(rf, X_train_mean_imputed, y_train,
                                                                     X_val_mean_imputed, y_val,
                                                                     hyperparams, {'random_state': 10})

print("Performance for best hyperparameters:")

y_train_best = rf_mean_imputed.predict_proba(X_train_mean_imputed)[:, 1]
print(f"- Train C-Index: {cindex(y_train, y_train_best):.4f}")

y_val_best = rf_mean_imputed.predict_proba(X_val_mean_imputed)[:, 1]
print(f"- Val C-Index: {cindex(y_val, y_val_best):.4f}")

y_test_imp = rf_mean_imputed.predict_proba(X_test)[:, 1]
print(f"- Test C-Index: {cindex(y_test, y_test_imp):.4f}")
# Out:
# [1/240] {'n_estimators': 100, 'max_depth': 1, 'min_samples_leaf': 1}
# Val C-Index: 0.7141512445200081
#
# [2/240] {'n_estimators': 100, 'max_depth': 1, 'min_samples_leaf': 2}
# Val C-Index: 0.7141512445200081
#
# [3/240] {'n_estimators': 100, 'max_depth': 1, 'min_samples_leaf': 3}
# Val C-Index: 0.7141512445200081
#
# [4/240] {'n_estimators': 100, 'max_depth': 2, 'min_samples_leaf': 1}
# Val C-Index: 0.732025952199488
#
# [5/240] {'n_estimators': 100, 'max_depth': 2, 'min_samples_leaf': 2}
# Val C-Index: 0.732025952199488
#
# [6/240] {'n_estimators': 100, 'max_depth': 2, 'min_samples_leaf': 3}
# Val C-Index: 0.7318478999606982
#
# [7/240] {'n_estimators': 100, 'max_depth': 3, 'min_samples_leaf': 1}
# Val C-Index: 0.7356966510979526
#
# [8/240] {'n_estimators': 100, 'max_depth': 3, 'min_samples_leaf': 2}
# Val C-Index: 0.7357161934168441
#
# [9/240] {'n_estimators': 100, 'max_depth': 3, 'min_samples_leaf': 3}
# Val C-Index: 0.7355381411780544
#
# [10/240] {'n_estimators': 100, 'max_depth': 4, 'min_samples_leaf': 1}
# Val C-Index: 0.7434951220200678
#
# [11/240] {'n_estimators': 100, 'max_depth': 4, 'min_samples_leaf': 2}
# Val C-Index: 0.7437448294281266
#
# [12/240] {'n_estimators': 100, 'max_depth': 4, 'min_samples_leaf': 3}
# Val C-Index: 0.7433713540004212
#
# [13/240] {'n_estimators': 101, 'max_depth': 1, 'min_samples_leaf': 1}
# Val C-Index: 0.7149307659069047
#
# [14/240] {'n_estimators': 101, 'max_depth': 1, 'min_samples_leaf': 2}
# Val C-Index: 0.7149307659069047
#
# [15/240] {'n_estimators': 101, 'max_depth': 1, 'min_samples_leaf': 3}
# Val C-Index: 0.7149307659069047
#
# [16/240] {'n_estimators': 101, 'max_depth': 2, 'min_samples_leaf': 1}
# Val C-Index: 0.7319086982861386
#
# [17/240] {'n_estimators': 101, 'max_depth': 2, 'min_samples_leaf': 2}
# Val C-Index: 0.7319086982861386
#
# [18/240] {'n_estimators': 101, 'max_depth': 2, 'min_samples_leaf': 3}
# Val C-Index: 0.7317132750972231
#
# [19/240] {'n_estimators': 101, 'max_depth': 3, 'min_samples_leaf': 1}
# Val C-Index: 0.7357227075231414
#
# [20/240] {'n_estimators': 101, 'max_depth': 3, 'min_samples_leaf': 2}
# Val C-Index: 0.7357444212107986
#
# [21/240] {'n_estimators': 101, 'max_depth': 3, 'min_samples_leaf': 3}
# Val C-Index: 0.7355750544470718
#
# [22/240] {'n_estimators': 101, 'max_depth': 4, 'min_samples_leaf': 1}
# Val C-Index: 0.7436514605712002
#
# [23/240] {'n_estimators': 101, 'max_depth': 4, 'min_samples_leaf': 2}
# Val C-Index: 0.7438794542916018
#
# [24/240] {'n_estimators': 101, 'max_depth': 4, 'min_samples_leaf': 3}
# Val C-Index: 0.7434039245319072
#
# [25/240] {'n_estimators': 102, 'max_depth': 1, 'min_samples_leaf': 1}
# Val C-Index: 0.714392266453004
#
# [26/240] {'n_estimators': 102, 'max_depth': 1, 'min_samples_leaf': 2}
# Val C-Index: 0.714392266453004
#
# [27/240] {'n_estimators': 102, 'max_depth': 1, 'min_samples_leaf': 3}
# Val C-Index: 0.714392266453004
#
# [28/240] {'n_estimators': 102, 'max_depth': 2, 'min_samples_leaf': 1}
# Val C-Index: 0.731561279283622
#
# [29/240] {'n_estimators': 102, 'max_depth': 2, 'min_samples_leaf': 2}
# Val C-Index: 0.731561279283622
#
# [30/240] {'n_estimators': 102, 'max_depth': 2, 'min_samples_leaf': 3}
# Val C-Index: 0.7313680274634722
#
# [31/240] {'n_estimators': 102, 'max_depth': 3, 'min_samples_leaf': 1}
# Val C-Index: 0.7353340325140759
#
# [32/240] {'n_estimators': 102, 'max_depth': 3, 'min_samples_leaf': 2}
# Val C-Index: 0.7353839739956877
#
# [33/240] {'n_estimators': 102, 'max_depth': 3, 'min_samples_leaf': 3}
# Val C-Index: 0.735221121338258
#
# [34/240] {'n_estimators': 102, 'max_depth': 4, 'min_samples_leaf': 1}
# Val C-Index: 0.7433908963193128
#
# [35/240] {'n_estimators': 102, 'max_depth': 4, 'min_samples_leaf': 2}
# Val C-Index: 0.7436330039366915
#
# [36/240] {'n_estimators': 102, 'max_depth': 4, 'min_samples_leaf': 3}
# Val C-Index: 0.7431922160772486
#
# [37/240] {'n_estimators': 103, 'max_depth': 1, 'min_samples_leaf': 1}
# Val C-Index: 0.715113160883226
#
# [38/240] {'n_estimators': 103, 'max_depth': 1, 'min_samples_leaf': 2}
# Val C-Index: 0.715113160883226
#
# [39/240] {'n_estimators': 103, 'max_depth': 1, 'min_samples_leaf': 3}
# Val C-Index: 0.715113160883226
#
# [40/240] {'n_estimators': 103, 'max_depth': 2, 'min_samples_leaf': 1}
# Val C-Index: 0.7318869845984813
#
# [41/240] {'n_estimators': 103, 'max_depth': 2, 'min_samples_leaf': 2}
# Val C-Index: 0.7318869845984813
#
# [42/240] {'n_estimators': 103, 'max_depth': 2, 'min_samples_leaf': 3}
# Val C-Index: 0.7317306460473488
#
# [43/240] {'n_estimators': 103, 'max_depth': 3, 'min_samples_leaf': 1}
# Val C-Index: 0.735453457796191
#
# [44/240] {'n_estimators': 103, 'max_depth': 3, 'min_samples_leaf': 2}
# Val C-Index: 0.7355446552843516
#
# [45/240] {'n_estimators': 103, 'max_depth': 3, 'min_samples_leaf': 3}
# Val C-Index: 0.7352960335606756
#
# [46/240] {'n_estimators': 103, 'max_depth': 4, 'min_samples_leaf': 1}
# Val C-Index: 0.7435385493953823
#
# [47/240] {'n_estimators': 103, 'max_depth': 4, 'min_samples_leaf': 2}
# Val C-Index: 0.7436753456276233
#
# [48/240] {'n_estimators': 103, 'max_depth': 4, 'min_samples_leaf': 3}
# Val C-Index: 0.7432595285089862
#
# [49/240] {'n_estimators': 104, 'max_depth': 1, 'min_samples_leaf': 1}
# Val C-Index: 0.7153867533477078
#
# [50/240] {'n_estimators': 104, 'max_depth': 1, 'min_samples_leaf': 2}
# Val C-Index: 0.7153867533477078
#
# [51/240] {'n_estimators': 104, 'max_depth': 1, 'min_samples_leaf': 3}
# Val C-Index: 0.7153867533477078
#
# [52/240] {'n_estimators': 104, 'max_depth': 2, 'min_samples_leaf': 1}
# Val C-Index: 0.7321497202191345
#
# [53/240] {'n_estimators': 104, 'max_depth': 2, 'min_samples_leaf': 2}
# Val C-Index: 0.7321497202191345
#
# [54/240] {'n_estimators': 104, 'max_depth': 2, 'min_samples_leaf': 3}
# Val C-Index: 0.7320194380931908
#
# [55/240] {'n_estimators': 104, 'max_depth': 3, 'min_samples_leaf': 1}
# Val C-Index: 0.7357357357357357
#
# [56/240] {'n_estimators': 104, 'max_depth': 3, 'min_samples_leaf': 2}
# Val C-Index: 0.7359203020808227
#
# [57/240] {'n_estimators': 104, 'max_depth': 3, 'min_samples_leaf': 3}
# Val C-Index: 0.7356760230946782
#
# [58/240] {'n_estimators': 104, 'max_depth': 4, 'min_samples_leaf': 1}
# Val C-Index: 0.7439445953545737
#
# [59/240] {'n_estimators': 104, 'max_depth': 4, 'min_samples_leaf': 2}
# Val C-Index: 0.7440770488492832
#
# [60/240] {'n_estimators': 104, 'max_depth': 4, 'min_samples_leaf': 3}
# Val C-Index: 0.743661231730646
#
# [61/240] {'n_estimators': 105, 'max_depth': 1, 'min_samples_leaf': 1}
# Val C-Index: 0.7151305318333517
#
# [62/240] {'n_estimators': 105, 'max_depth': 1, 'min_samples_leaf': 2}
# Val C-Index: 0.7151305318333517
#
# [63/240] {'n_estimators': 105, 'max_depth': 1, 'min_samples_leaf': 3}
# Val C-Index: 0.7151305318333517
#
# [64/240] {'n_estimators': 105, 'max_depth': 2, 'min_samples_leaf': 1}
# Val C-Index: 0.7316503054030169
#
# [65/240] {'n_estimators': 105, 'max_depth': 2, 'min_samples_leaf': 2}
# Val C-Index: 0.7316503054030169
#
# [66/240] {'n_estimators': 105, 'max_depth': 2, 'min_samples_leaf': 3}
# Val C-Index: 0.7314961382206502
#
# [67/240] {'n_estimators': 105, 'max_depth': 3, 'min_samples_leaf': 1}
# Val C-Index: 0.7356488809851066
#
# [68/240] {'n_estimators': 105, 'max_depth': 3, 'min_samples_leaf': 2}
# Val C-Index: 0.7357313929982042
#
# [69/240] {'n_estimators': 105, 'max_depth': 3, 'min_samples_leaf': 3}
# Val C-Index: 0.735484942643294
#
# [70/240] {'n_estimators': 105, 'max_depth': 4, 'min_samples_leaf': 1}
# Val C-Index: 0.7433952390568442
#
# [71/240] {'n_estimators': 105, 'max_depth': 4, 'min_samples_leaf': 2}
# Val C-Index: 0.7435906622457599
#
# [72/240] {'n_estimators': 105, 'max_depth': 4, 'min_samples_leaf': 3}
# Val C-Index: 0.7431965588147801
#
# [73/240] {'n_estimators': 106, 'max_depth': 1, 'min_samples_leaf': 1}
# Val C-Index: 0.7145855182731539
#
# [74/240] {'n_estimators': 106, 'max_depth': 1, 'min_samples_leaf': 2}
# Val C-Index: 0.7145855182731539
#
# [75/240] {'n_estimators': 106, 'max_depth': 1, 'min_samples_leaf': 3}
# Val C-Index: 0.7145855182731539
#
# [76/240] {'n_estimators': 106, 'max_depth': 2, 'min_samples_leaf': 1}
# Val C-Index: 0.7314874527455872
#
# [77/240] {'n_estimators': 106, 'max_depth': 2, 'min_samples_leaf': 2}
# Val C-Index: 0.7314874527455872
#
# [78/240] {'n_estimators': 106, 'max_depth': 2, 'min_samples_leaf': 3}
# Val C-Index: 0.7313528278821121
#
# [79/240] {'n_estimators': 106, 'max_depth': 3, 'min_samples_leaf': 1}
# Val C-Index: 0.7354491150586595
#
# [80/240] {'n_estimators': 106, 'max_depth': 3, 'min_samples_leaf': 2}
# Val C-Index: 0.7355381411780544
# [81/240] {'n_estimators': 106, 'max_depth': 3, 'min_samples_leaf': 3}
# Val C-Index: 0.7353459750422874
#
# [82/240] {'n_estimators': 106, 'max_depth': 4, 'min_samples_leaf': 1}
# Val C-Index: 0.7432975274623864
#
# [83/240] {'n_estimators': 106, 'max_depth': 4, 'min_samples_leaf': 2}
# Val C-Index: 0.7434755797011763
#
# [84/240] {'n_estimators': 106, 'max_depth': 4, 'min_samples_leaf': 3}
# Val C-Index: 0.7430641053200706
#
# [85/240] {'n_estimators': 107, 'max_depth': 1, 'min_samples_leaf': 1}
# Val C-Index: 0.7167666581983285
#
# [86/240] {'n_estimators': 107, 'max_depth': 1, 'min_samples_leaf': 2}
# Val C-Index: 0.7167666581983285
#
# [87/240] {'n_estimators': 107, 'max_depth': 1, 'min_samples_leaf': 3}
# Val C-Index: 0.7167666581983285
#
# [88/240] {'n_estimators': 107, 'max_depth': 2, 'min_samples_leaf': 1}
# Val C-Index: 0.7319738393491105
#
# [89/240] {'n_estimators': 107, 'max_depth': 2, 'min_samples_leaf': 2}
# Val C-Index: 0.7319738393491105
#
# [90/240] {'n_estimators': 107, 'max_depth': 2, 'min_samples_leaf': 3}
# Val C-Index: 0.7318218435355095
#
# [91/240] {'n_estimators': 107, 'max_depth': 3, 'min_samples_leaf': 1}
# Val C-Index: 0.7357867629017304
#
# [92/240] {'n_estimators': 107, 'max_depth': 3, 'min_samples_leaf': 2}
# Val C-Index: 0.7358041338518562
#
# [93/240] {'n_estimators': 107, 'max_depth': 3, 'min_samples_leaf': 3}
# Val C-Index: 0.7357465925795644
#
# [94/240] {'n_estimators': 107, 'max_depth': 4, 'min_samples_leaf': 1}
# Val C-Index: 0.7432226152399688
#
# [95/240] {'n_estimators': 107, 'max_depth': 4, 'min_samples_leaf': 2}
# Val C-Index: 0.7433843822130156
#
# [96/240] {'n_estimators': 107, 'max_depth': 4, 'min_samples_leaf': 3}
# Val C-Index: 0.7431118754329167
#
# [97/240] {'n_estimators': 108, 'max_depth': 1, 'min_samples_leaf': 1}
# Val C-Index: 0.7167579727232656
#
# [98/240] {'n_estimators': 108, 'max_depth': 1, 'min_samples_leaf': 2}
# Val C-Index: 0.7167579727232656
#
# [99/240] {'n_estimators': 108, 'max_depth': 1, 'min_samples_leaf': 3}
# Val C-Index: 0.7167579727232656
#
# [100/240] {'n_estimators': 108, 'max_depth': 2, 'min_samples_leaf': 1}
# Val C-Index: 0.7316807045657371
#
# [101/240] {'n_estimators': 108, 'max_depth': 2, 'min_samples_leaf': 2}
# Val C-Index: 0.7316807045657371
#
# [102/240] {'n_estimators': 108, 'max_depth': 2, 'min_samples_leaf': 3}
# Val C-Index: 0.731513509170776
#
# [103/240] {'n_estimators': 108, 'max_depth': 3, 'min_samples_leaf': 1}
# Val C-Index: 0.7354415152679795
#
# [104/240] {'n_estimators': 108, 'max_depth': 3, 'min_samples_leaf': 2}
# Val C-Index: 0.735550083706266
#
# [105/240] {'n_estimators': 108, 'max_depth': 3, 'min_samples_leaf': 3}
# Val C-Index: 0.7354838569589112
#
# [106/240] {'n_estimators': 108, 'max_depth': 4, 'min_samples_leaf': 1}
# Val C-Index: 0.7431791878646542
#
# [107/240] {'n_estimators': 108, 'max_depth': 4, 'min_samples_leaf': 2}
# Val C-Index: 0.743373525369187
#
# [108/240] {'n_estimators': 108, 'max_depth': 4, 'min_samples_leaf': 3}
# Val C-Index: 0.7430575912137735
#
# [109/240] {'n_estimators': 109, 'max_depth': 1, 'min_samples_leaf': 1}
# Val C-Index: 0.7168513415801919
#
# [110/240] {'n_estimators': 109, 'max_depth': 1, 'min_samples_leaf': 2}
# Val C-Index: 0.7168513415801919
#
# [111/240] {'n_estimators': 109, 'max_depth': 1, 'min_samples_leaf': 3}
# Val C-Index: 0.7168513415801919
#
# [112/240] {'n_estimators': 109, 'max_depth': 2, 'min_samples_leaf': 1}
# Val C-Index: 0.7316611622468455
#
# [113/240] {'n_estimators': 109, 'max_depth': 2, 'min_samples_leaf': 2}
# Val C-Index: 0.7316611622468455
#
# [114/240] {'n_estimators': 109, 'max_depth': 2, 'min_samples_leaf': 3}
# Val C-Index: 0.7314939668518844
#
# [115/240] {'n_estimators': 109, 'max_depth': 3, 'min_samples_leaf': 1}
# Val C-Index: 0.7355261986498429
#
# [116/240] {'n_estimators': 109, 'max_depth': 3, 'min_samples_leaf': 2}
# Val C-Index: 0.7356021965566434
#
# [117/240] {'n_estimators': 109, 'max_depth': 3, 'min_samples_leaf': 3}
# Val C-Index: 0.7355294557029914
#
# [118/240] {'n_estimators': 109, 'max_depth': 4, 'min_samples_leaf': 1}
# Val C-Index: 0.7433029558843008
#
# [119/240] {'n_estimators': 109, 'max_depth': 4, 'min_samples_leaf': 2}
# Val C-Index: 0.7435580917142739
#
# [120/240] {'n_estimators': 109, 'max_depth': 4, 'min_samples_leaf': 3}
# Val C-Index: 0.7431118754329167
#
# [121/240] {'n_estimators': 110, 'max_depth': 1, 'min_samples_leaf': 1}
# Val C-Index: 0.7169848807592842
#
# [122/240] {'n_estimators': 110, 'max_depth': 1, 'min_samples_leaf': 2}
# Val C-Index: 0.7169848807592842
#
# [123/240] {'n_estimators': 110, 'max_depth': 1, 'min_samples_leaf': 3}
# Val C-Index: 0.7169848807592842
#
# [124/240] {'n_estimators': 110, 'max_depth': 2, 'min_samples_leaf': 1}
# Val C-Index: 0.7317784161601949
#
# [125/240] {'n_estimators': 110, 'max_depth': 2, 'min_samples_leaf': 2}
# Val C-Index: 0.7317784161601949
#
# [126/240] {'n_estimators': 110, 'max_depth': 2, 'min_samples_leaf': 3}
# Val C-Index: 0.7316220776090624
#
# [127/240] {'n_estimators': 110, 'max_depth': 3, 'min_samples_leaf': 1}
# Val C-Index: 0.7357715633203703
#
# [128/240] {'n_estimators': 110, 'max_depth': 3, 'min_samples_leaf': 2}
# Val C-Index: 0.735830190277045
#
# [129/240] {'n_estimators': 110, 'max_depth': 3, 'min_samples_leaf': 3}
# Val C-Index: 0.7357531066858616
#
# [130/240] {'n_estimators': 110, 'max_depth': 4, 'min_samples_leaf': 1}
# Val C-Index: 0.7436742599432404
#
# [131/240] {'n_estimators': 110, 'max_depth': 4, 'min_samples_leaf': 2}
# Val C-Index: 0.7438599119727103
#
# [132/240] {'n_estimators': 110, 'max_depth': 4, 'min_samples_leaf': 3}
# Val C-Index: 0.7434093529538215
#
# [133/240] {'n_estimators': 111, 'max_depth': 1, 'min_samples_leaf': 1}
# Val C-Index: 0.7174495536751502
#
# [134/240] {'n_estimators': 111, 'max_depth': 1, 'min_samples_leaf': 2}
# Val C-Index: 0.7174495536751502
#
# [135/240] {'n_estimators': 111, 'max_depth': 1, 'min_samples_leaf': 3}
# Val C-Index: 0.7174495536751502
#
# [136/240] {'n_estimators': 111, 'max_depth': 2, 'min_samples_leaf': 1}
# Val C-Index: 0.7322843450826098
#
# [137/240] {'n_estimators': 111, 'max_depth': 2, 'min_samples_leaf': 2}
# Val C-Index: 0.7322843450826098
#
# [138/240] {'n_estimators': 111, 'max_depth': 2, 'min_samples_leaf': 3}
# Val C-Index: 0.7321627484317289
#
# [139/240] {'n_estimators': 111, 'max_depth': 3, 'min_samples_leaf': 1}
# Val C-Index: 0.7360690408412751
#
# [140/240] {'n_estimators': 111, 'max_depth': 3, 'min_samples_leaf': 2}
# Val C-Index: 0.7360842404226352
#
# [141/240] {'n_estimators': 111, 'max_depth': 3, 'min_samples_leaf': 3}
# Val C-Index: 0.7360636124193608
#
# [142/240] {'n_estimators': 111, 'max_depth': 4, 'min_samples_leaf': 1}
# Val C-Index: 0.7439804229392082
#
# [143/240] {'n_estimators': 111, 'max_depth': 4, 'min_samples_leaf': 2}
# Val C-Index: 0.7441204762245976
#
# [144/240] {'n_estimators': 111, 'max_depth': 4, 'min_samples_leaf': 3}
# Val C-Index: 0.7438262557568415
#
# [145/240] {'n_estimators': 112, 'max_depth': 1, 'min_samples_leaf': 1}
# Val C-Index: 0.7171694471043711
#
# [146/240] {'n_estimators': 112, 'max_depth': 1, 'min_samples_leaf': 2}
# Val C-Index: 0.7171694471043711
#
# [147/240] {'n_estimators': 112, 'max_depth': 1, 'min_samples_leaf': 3}
# Val C-Index: 0.7171694471043711
#
# [148/240] {'n_estimators': 112, 'max_depth': 2, 'min_samples_leaf': 1}
# Val C-Index: 0.7322930305576726
#
# [149/240] {'n_estimators': 112, 'max_depth': 2, 'min_samples_leaf': 2}
# Val C-Index: 0.7322930305576726
#
# [150/240] {'n_estimators': 112, 'max_depth': 2, 'min_samples_leaf': 3}
# Val C-Index: 0.7321475488503688
#
# [151/240] {'n_estimators': 112, 'max_depth': 3, 'min_samples_leaf': 1}
# Val C-Index: 0.7363469760432884
#
# [152/240] {'n_estimators': 112, 'max_depth': 3, 'min_samples_leaf': 2}
# Val C-Index: 0.7363969175249002
#
# [153/240] {'n_estimators': 112, 'max_depth': 3, 'min_samples_leaf': 3}
# Val C-Index: 0.7363632613090314
#
# [154/240] {'n_estimators': 112, 'max_depth': 4, 'min_samples_leaf': 1}
# Val C-Index: 0.7442105880283755
#
# [155/240] {'n_estimators': 112, 'max_depth': 4, 'min_samples_leaf': 2}
# Val C-Index: 0.7443701836326565
#
# [156/240] {'n_estimators': 112, 'max_depth': 4, 'min_samples_leaf': 3}
# Val C-Index: 0.744102019590089
#
# [157/240] {'n_estimators': 113, 'max_depth': 1, 'min_samples_leaf': 1}
# Val C-Index: 0.7174234972499615
#
# [158/240] {'n_estimators': 113, 'max_depth': 1, 'min_samples_leaf': 2}
# Val C-Index: 0.7174234972499615
#
# [159/240] {'n_estimators': 113, 'max_depth': 1, 'min_samples_leaf': 3}
# Val C-Index: 0.7174234972499615
#
# [160/240] {'n_estimators': 113, 'max_depth': 2, 'min_samples_leaf': 1}
# Val C-Index: 0.732690391041801
# [161/240] {'n_estimators': 113, 'max_depth': 2, 'min_samples_leaf': 2}
# Val C-Index: 0.732690391041801
#
# [162/240] {'n_estimators': 113, 'max_depth': 2, 'min_samples_leaf': 3}
# Val C-Index: 0.7325666230221545
#
# [163/240] {'n_estimators': 113, 'max_depth': 3, 'min_samples_leaf': 1}
# Val C-Index: 0.7364772581692322
#
# [164/240] {'n_estimators': 113, 'max_depth': 3, 'min_samples_leaf': 2}
# Val C-Index: 0.7364360021626833
#
# [165/240] {'n_estimators': 113, 'max_depth': 3, 'min_samples_leaf': 3}
# Val C-Index: 0.7363806322591572
#
# [166/240] {'n_estimators': 113, 'max_depth': 4, 'min_samples_leaf': 1}
# Val C-Index: 0.7442496726661586
#
# [167/240] {'n_estimators': 113, 'max_depth': 4, 'min_samples_leaf': 2}
# Val C-Index: 0.7444114396392054
#
# [168/240] {'n_estimators': 113, 'max_depth': 4, 'min_samples_leaf': 3}
# Val C-Index: 0.7442409871910957
#
# [169/240] {'n_estimators': 114, 'max_depth': 1, 'min_samples_leaf': 1}
# Val C-Index: 0.7179489684912679
#
# [170/240] {'n_estimators': 114, 'max_depth': 1, 'min_samples_leaf': 2}
# Val C-Index: 0.7179489684912679
#
# [171/240] {'n_estimators': 114, 'max_depth': 1, 'min_samples_leaf': 3}
# Val C-Index: 0.7179489684912679
#
# [172/240] {'n_estimators': 114, 'max_depth': 2, 'min_samples_leaf': 1}
# Val C-Index: 0.7333526585153484
#
# [173/240] {'n_estimators': 114, 'max_depth': 2, 'min_samples_leaf': 2}
# Val C-Index: 0.7333526585153484
#
# [174/240] {'n_estimators': 114, 'max_depth': 2, 'min_samples_leaf': 3}
# Val C-Index: 0.7332310618644675
#
# [175/240] {'n_estimators': 114, 'max_depth': 3, 'min_samples_leaf': 1}
# Val C-Index: 0.7366249112453017
#
# [176/240] {'n_estimators': 114, 'max_depth': 3, 'min_samples_leaf': 2}
# Val C-Index: 0.736694395045805
#
# [177/240] {'n_estimators': 114, 'max_depth': 3, 'min_samples_leaf': 3}
# Val C-Index: 0.7365869122919014
#
# [178/240] {'n_estimators': 114, 'max_depth': 4, 'min_samples_leaf': 1}
# Val C-Index: 0.7442279589785012
#
# [179/240] {'n_estimators': 114, 'max_depth': 4, 'min_samples_leaf': 2}
# Val C-Index: 0.7444461815394571
#
# [180/240] {'n_estimators': 114, 'max_depth': 4, 'min_samples_leaf': 3}
# Val C-Index: 0.7441172191714491
#
# [181/240] {'n_estimators': 115, 'max_depth': 1, 'min_samples_leaf': 1}
# Val C-Index: 0.7176471482328315
#
# [182/240] {'n_estimators': 115, 'max_depth': 1, 'min_samples_leaf': 2}
# Val C-Index: 0.7176471482328315
#
# [183/240] {'n_estimators': 115, 'max_depth': 1, 'min_samples_leaf': 3}
# Val C-Index: 0.7176471482328315
#
# [184/240] {'n_estimators': 115, 'max_depth': 2, 'min_samples_leaf': 1}
# Val C-Index: 0.7326838769355039
#
# [185/240] {'n_estimators': 115, 'max_depth': 2, 'min_samples_leaf': 2}
# Val C-Index: 0.7326838769355039
#
# [186/240] {'n_estimators': 115, 'max_depth': 2, 'min_samples_leaf': 3}
# Val C-Index: 0.7325796512347489
#
# [187/240] {'n_estimators': 115, 'max_depth': 3, 'min_samples_leaf': 1}
# Val C-Index: 0.7364533731128091
#
# [188/240] {'n_estimators': 115, 'max_depth': 3, 'min_samples_leaf': 2}
# Val C-Index: 0.7363925747873687
#
# [189/240] {'n_estimators': 115, 'max_depth': 3, 'min_samples_leaf': 3}
# Val C-Index: 0.7362655497145736
#
# [190/240] {'n_estimators': 115, 'max_depth': 4, 'min_samples_leaf': 1}
# Val C-Index: 0.7439869370455053
#
# [191/240] {'n_estimators': 115, 'max_depth': 4, 'min_samples_leaf': 2}
# Val C-Index: 0.7443289276261077
#
# [192/240] {'n_estimators': 115, 'max_depth': 4, 'min_samples_leaf': 3}
# Val C-Index: 0.7440108221019284
#
# [193/240] {'n_estimators': 116, 'max_depth': 1, 'min_samples_leaf': 1}
# Val C-Index: 0.7178469141592786
#
# [194/240] {'n_estimators': 116, 'max_depth': 1, 'min_samples_leaf': 2}
# Val C-Index: 0.7178469141592786
#
# [195/240] {'n_estimators': 116, 'max_depth': 1, 'min_samples_leaf': 3}
# Val C-Index: 0.7178469141592786
#
# [196/240] {'n_estimators': 116, 'max_depth': 2, 'min_samples_leaf': 1}
# Val C-Index: 0.7327577034735386
#
# [197/240] {'n_estimators': 116, 'max_depth': 2, 'min_samples_leaf': 2}
# Val C-Index: 0.7327577034735386
#
# [198/240] {'n_estimators': 116, 'max_depth': 2, 'min_samples_leaf': 3}
# Val C-Index: 0.7326469636664864
#
# [199/240] {'n_estimators': 116, 'max_depth': 3, 'min_samples_leaf': 1}
# Val C-Index: 0.7364208025813231
#
# [200/240] {'n_estimators': 116, 'max_depth': 3, 'min_samples_leaf': 2}
# Val C-Index: 0.7363686897309457
#
# [201/240] {'n_estimators': 116, 'max_depth': 3, 'min_samples_leaf': 3}
# Val C-Index: 0.7362069227578989
#
# [202/240] {'n_estimators': 116, 'max_depth': 4, 'min_samples_leaf': 1}
# Val C-Index: 0.7440955054837918
#
# [203/240] {'n_estimators': 116, 'max_depth': 4, 'min_samples_leaf': 2}
# Val C-Index: 0.7443832118452509
#
# [204/240] {'n_estimators': 116, 'max_depth': 4, 'min_samples_leaf': 3}
# Val C-Index: 0.743950023776488
#
# [205/240] {'n_estimators': 117, 'max_depth': 1, 'min_samples_leaf': 1}
# Val C-Index: 0.7173084147053779
#
# [206/240] {'n_estimators': 117, 'max_depth': 1, 'min_samples_leaf': 2}
# Val C-Index: 0.7173084147053779
#
# [207/240] {'n_estimators': 117, 'max_depth': 1, 'min_samples_leaf': 3}
# Val C-Index: 0.7173084147053779
#
# [208/240] {'n_estimators': 117, 'max_depth': 2, 'min_samples_leaf': 1}
# Val C-Index: 0.7326447922977207
#
# [209/240] {'n_estimators': 117, 'max_depth': 2, 'min_samples_leaf': 2}
# Val C-Index: 0.7326447922977207
#
# [210/240] {'n_estimators': 117, 'max_depth': 2, 'min_samples_leaf': 3}
# Val C-Index: 0.7325427379657314
#
# [211/240] {'n_estimators': 117, 'max_depth': 3, 'min_samples_leaf': 1}
# Val C-Index: 0.7362992059304424
#
# [212/240] {'n_estimators': 117, 'max_depth': 3, 'min_samples_leaf': 2}
# Val C-Index: 0.7362557785551278
#
# [213/240] {'n_estimators': 117, 'max_depth': 3, 'min_samples_leaf': 3}
# Val C-Index: 0.736085326107018
#
# [214/240] {'n_estimators': 117, 'max_depth': 4, 'min_samples_leaf': 1}
# Val C-Index: 0.7440803059024317
#
# [215/240] {'n_estimators': 117, 'max_depth': 4, 'min_samples_leaf': 2}
# Val C-Index: 0.7444635524895828
#
# [216/240] {'n_estimators': 117, 'max_depth': 4, 'min_samples_leaf': 3}
# Val C-Index: 0.7440390498958829
#
# [217/240] {'n_estimators': 118, 'max_depth': 1, 'min_samples_leaf': 1}
# Val C-Index: 0.7172085317421543
#
# [218/240] {'n_estimators': 118, 'max_depth': 1, 'min_samples_leaf': 2}
# Val C-Index: 0.7172085317421543
#
# [219/240] {'n_estimators': 118, 'max_depth': 1, 'min_samples_leaf': 3}
# Val C-Index: 0.7172085317421543
#
# [220/240] {'n_estimators': 118, 'max_depth': 2, 'min_samples_leaf': 1}
# Val C-Index: 0.7327685603173673
#
# [221/240] {'n_estimators': 118, 'max_depth': 2, 'min_samples_leaf': 2}
# Val C-Index: 0.7327685603173673
#
# [222/240] {'n_estimators': 118, 'max_depth': 2, 'min_samples_leaf': 3}
# Val C-Index: 0.7327099333606926
#
# [223/240] {'n_estimators': 118, 'max_depth': 3, 'min_samples_leaf': 1}
# Val C-Index: 0.7363339478306941
#
# [224/240] {'n_estimators': 118, 'max_depth': 3, 'min_samples_leaf': 2}
# Val C-Index: 0.7363382905682255
#
# [225/240] {'n_estimators': 118, 'max_depth': 3, 'min_samples_leaf': 3}
# Val C-Index: 0.7361352675886298
#
# [226/240] {'n_estimators': 118, 'max_depth': 4, 'min_samples_leaf': 1}
# Val C-Index: 0.7441031052744719
#
# [227/240] {'n_estimators': 118, 'max_depth': 4, 'min_samples_leaf': 2}
# Val C-Index: 0.7444602954364342
#
# [228/240] {'n_estimators': 118, 'max_depth': 4, 'min_samples_leaf': 3}
# Val C-Index: 0.7439044250324077
#
# [229/240] {'n_estimators': 119, 'max_depth': 1, 'min_samples_leaf': 1}
# Val C-Index: 0.7180618796670858
#
# [230/240] {'n_estimators': 119, 'max_depth': 1, 'min_samples_leaf': 2}
# Val C-Index: 0.7180618796670858
#
# [231/240] {'n_estimators': 119, 'max_depth': 1, 'min_samples_leaf': 3}
# Val C-Index: 0.7180618796670858
#
# [232/240] {'n_estimators': 119, 'max_depth': 2, 'min_samples_leaf': 1}
# Val C-Index: 0.7332050054392788
#
# [233/240] {'n_estimators': 119, 'max_depth': 2, 'min_samples_leaf': 2}
# Val C-Index: 0.7332050054392788
#
# [234/240] {'n_estimators': 119, 'max_depth': 2, 'min_samples_leaf': 3}
# Val C-Index: 0.7330964370009924
#
# [235/240] {'n_estimators': 119, 'max_depth': 3, 'min_samples_leaf': 1}
# Val C-Index: 0.7364989718568894
#
# [236/240] {'n_estimators': 119, 'max_depth': 3, 'min_samples_leaf': 2}
# Val C-Index: 0.7364273166876204
#
# [237/240] {'n_estimators': 119, 'max_depth': 3, 'min_samples_leaf': 3}
# Val C-Index: 0.7362850920334651
#
# [238/240] {'n_estimators': 119, 'max_depth': 4, 'min_samples_leaf': 1}
# Val C-Index: 0.7441400185434892
#
# [239/240] {'n_estimators': 119, 'max_depth': 4, 'min_samples_leaf': 2}
# Val C-Index: 0.7444016684797596
# [240/240] {'n_estimators': 119, 'max_depth': 4, 'min_samples_leaf': 3}
# Val C-Index: 0.7438848827135162
#
# Performance for best hyperparameters:
# - Train C-Index: 0.7864
# - Val C-Index: 0.7445
# - Test C-Index: 0.7793

# %% [markdown]
# #### Expected output
# Note, your actual c-index values will vary depending on the hyper-parameters that you choose.
# - Try to get a good Test c-index, similar these numbers below:
#
# ```Python
# Performance for best hyperparameters:
# - Train C-Index: 0.8109
# - Val C-Index: 0.7495
# - Test C-Index: 0.7805
# ```

# %% [markdown]
# Next, we will apply another imputation strategy, known as **multivariate feature imputation**, using scikit-learn's `IterativeImputer` class (see the [documentation](https://scikit-learn.org/stable/modules/impute.html#iterative-imputer)).
#
# With this strategy, for each feature that is missing values, a regression model is trained to predict observed values based on all of the other features, and the missing values are inferred using this model.
# As a single iteration across all features may not be enough to impute all missing values, several iterations may be performed, hence the name of the class `IterativeImputer`.
#
# In the next cell, use `IterativeImputer` to perform multivariate feature imputation.
#
# > Note that the first time the cell is run, `imputer.fit(X_train)` may fail with the message `LinAlgError: SVD did not converge`: simply re-run the cell.

# %%
# Impute using regression on other covariates
imputer = IterativeImputer(random_state=0, sample_posterior=False, max_iter=1, min_value=0)
imputer.fit(X_train)
X_train_imputed = pd.DataFrame(imputer.transform(X_train), columns=X_train.columns)
X_val_imputed = pd.DataFrame(imputer.transform(X_val), columns=X_val.columns)

# %% [markdown]
# <a name='Ex-6'></a>
# ### Exercise 6
#
# Perform a hyperparameter grid search to find the best-performing random forest model, and report results on the test set. Define the parameter ranges for the hyperparameter search in the next cell, and run the cell.
#
# #### Target performance
#
# Try to get a text c-index of at least 0.74 or higher.

# %% [markdown]
# <details>
# <summary>
#     <font size="3" color="darkgreen"><b>Hints</b></font>
# </summary>
# <p>
# <ul>
#     <li>n_estimators: try values greater than 100</li>
#     <li>max_depth: try values in the range 1 to 100</li>
#     <li>min_samples_leaf: try float values below .5 and/or int values greater than 2</li>
# </ul>
# </p>

# %%
# Define ranges for the random forest hyperparameter search 
hyperparams = {
    ### START CODE HERE (REPLACE array values with your code) ###

    # how many trees should be in the forest (int)
    'n_estimators': range(110,130),

    # the maximum depth of trees in the forest (int)
    'max_depth': [3,4,5],

    # the minimum number of samples in a leaf as a fraction
    # of the total number of samples in the training set
    # Can be int (in which case that is the minimum number)
    # or float (in which case the minimum is that fraction of the
    # number of training set samples)
    'min_samples_leaf': [1,2,3],

    ### END CODE HERE ###
}

# %%
# UNQ_C6 (UNIQUE CELL IDENTIFIER, DO NOT EDIT)
rf = RandomForestClassifier

rf_imputed, best_hyperparams_imputed = holdout_grid_search(rf, X_train_imputed, y_train,
                                                           X_val_imputed, y_val,
                                                           hyperparams, {'random_state': 10})

print("Performance for best hyperparameters:")

y_train_best = rf_imputed.predict_proba(X_train_imputed)[:, 1]
print(f"- Train C-Index: {cindex(y_train, y_train_best):.4f}")

y_val_best = rf_imputed.predict_proba(X_val_imputed)[:, 1]
print(f"- Val C-Index: {cindex(y_val, y_val_best):.4f}")

y_test_imp = rf_imputed.predict_proba(X_test)[:, 1]
print(f"- Test C-Index: {cindex(y_test, y_test_imp):.4f}")
# Out:
# [1/180] {'n_estimators': 110, 'max_depth': 3, 'min_samples_leaf': 1}
# Val C-Index: 0.7339997264075355
#
# [2/180] {'n_estimators': 110, 'max_depth': 3, 'min_samples_leaf': 2}
# Val C-Index: 0.7339888695637069
#
# [3/180] {'n_estimators': 110, 'max_depth': 3, 'min_samples_leaf': 3}
# Val C-Index: 0.7338976720755462
#
# [4/180] {'n_estimators': 110, 'max_depth': 4, 'min_samples_leaf': 1}
# Val C-Index: 0.7404736623825561
#
# [5/180] {'n_estimators': 110, 'max_depth': 4, 'min_samples_leaf': 2}
# Val C-Index: 0.7406973133654262
#
# [6/180] {'n_estimators': 110, 'max_depth': 4, 'min_samples_leaf': 3}
# Val C-Index: 0.7402956101437663
#
# [7/180] {'n_estimators': 110, 'max_depth': 5, 'min_samples_leaf': 1}
# Val C-Index: 0.7451442765976388
#
# [8/180] {'n_estimators': 110, 'max_depth': 5, 'min_samples_leaf': 2}
# Val C-Index: 0.7444972087054517
#
# [9/180] {'n_estimators': 110, 'max_depth': 5, 'min_samples_leaf': 3}
# Val C-Index: 0.7432443289276262
#
# [10/180] {'n_estimators': 111, 'max_depth': 3, 'min_samples_leaf': 1}
# Val C-Index: 0.734331945828692
#
# [11/180] {'n_estimators': 111, 'max_depth': 3, 'min_samples_leaf': 2}
# Val C-Index: 0.7343623449914123
#
# [12/180] {'n_estimators': 111, 'max_depth': 3, 'min_samples_leaf': 3}
# Val C-Index: 0.7342972039284403
#
# [13/180] {'n_estimators': 111, 'max_depth': 4, 'min_samples_leaf': 1}
# Val C-Index: 0.7408883938168103
#
# [14/180] {'n_estimators': 111, 'max_depth': 4, 'min_samples_leaf': 2}
# Val C-Index: 0.7410794742681944
#
# [15/180] {'n_estimators': 111, 'max_depth': 4, 'min_samples_leaf': 3}
# Val C-Index: 0.7407298838969121
#
# [16/180] {'n_estimators': 111, 'max_depth': 5, 'min_samples_leaf': 1}
# Val C-Index: 0.7452050749230793
#
# [17/180] {'n_estimators': 111, 'max_depth': 5, 'min_samples_leaf': 2}
# Val C-Index: 0.7446057771437381
#
# [18/180] {'n_estimators': 111, 'max_depth': 5, 'min_samples_leaf': 3}
# Val C-Index: 0.7431748451271227
#
# [19/180] {'n_estimators': 112, 'max_depth': 3, 'min_samples_leaf': 1}
# Val C-Index: 0.7342190346528741
#
# [20/180] {'n_estimators': 112, 'max_depth': 3, 'min_samples_leaf': 2}
# Val C-Index: 0.7342233773904056
#
# [21/180] {'n_estimators': 112, 'max_depth': 3, 'min_samples_leaf': 3}
# Val C-Index: 0.7342624620281887
#
# [22/180] {'n_estimators': 112, 'max_depth': 4, 'min_samples_leaf': 1}
# Val C-Index: 0.7409774199362051
#
# [23/180] {'n_estimators': 112, 'max_depth': 4, 'min_samples_leaf': 2}
# Val C-Index: 0.7411446153311663
#
# [24/180] {'n_estimators': 112, 'max_depth': 4, 'min_samples_leaf': 3}
# Val C-Index: 0.7407885108535868
#
# [25/180] {'n_estimators': 112, 'max_depth': 5, 'min_samples_leaf': 1}
# Val C-Index: 0.7454287259059493
#
# [26/180] {'n_estimators': 112, 'max_depth': 5, 'min_samples_leaf': 2}
# Val C-Index: 0.7449445106711918
#
# [27/180] {'n_estimators': 112, 'max_depth': 5, 'min_samples_leaf': 3}
# Val C-Index: 0.7435070645482793
#
# [28/180] {'n_estimators': 113, 'max_depth': 3, 'min_samples_leaf': 1}
# Val C-Index: 0.7341973209652168
#
# [29/180] {'n_estimators': 113, 'max_depth': 3, 'min_samples_leaf': 2}
# Val C-Index: 0.7343037180347376
#
# [30/180] {'n_estimators': 113, 'max_depth': 3, 'min_samples_leaf': 3}
# Val C-Index: 0.7343058894035033
#
# [31/180] {'n_estimators': 113, 'max_depth': 4, 'min_samples_leaf': 1}
# Val C-Index: 0.7411098734309146
#
# [32/180] {'n_estimators': 113, 'max_depth': 4, 'min_samples_leaf': 2}
# Val C-Index: 0.7413161534636589
#
# [33/180] {'n_estimators': 113, 'max_depth': 4, 'min_samples_leaf': 3}
# Val C-Index: 0.7409491921422507
#
# [34/180] {'n_estimators': 113, 'max_depth': 5, 'min_samples_leaf': 1}
# Val C-Index: 0.7454808387563269
#
# [35/180] {'n_estimators': 113, 'max_depth': 5, 'min_samples_leaf': 2}
# Val C-Index: 0.7449249683523003
#
# [36/180] {'n_estimators': 113, 'max_depth': 5, 'min_samples_leaf': 3}
# Val C-Index: 0.7435200927608737
#
# [37/180] {'n_estimators': 114, 'max_depth': 3, 'min_samples_leaf': 1}
# Val C-Index: 0.7338933293380148
#
# [38/180] {'n_estimators': 114, 'max_depth': 3, 'min_samples_leaf': 2}
# Val C-Index: 0.7339497849259238
#
# [39/180] {'n_estimators': 114, 'max_depth': 3, 'min_samples_leaf': 3}
# Val C-Index: 0.733971498613581
#
# [40/180] {'n_estimators': 114, 'max_depth': 4, 'min_samples_leaf': 1}
# Val C-Index: 0.7407298838969121
#
# [41/180] {'n_estimators': 114, 'max_depth': 4, 'min_samples_leaf': 2}
# Val C-Index: 0.7410816456369602
#
# [42/180] {'n_estimators': 114, 'max_depth': 4, 'min_samples_leaf': 3}
# Val C-Index: 0.7406973133654262
#
# [43/180] {'n_estimators': 114, 'max_depth': 5, 'min_samples_leaf': 1}
# Val C-Index: 0.7453570707366802
#
# [44/180] {'n_estimators': 114, 'max_depth': 5, 'min_samples_leaf': 2}
# Val C-Index: 0.7449054260334087
#
# [45/180] {'n_estimators': 114, 'max_depth': 5, 'min_samples_leaf': 3}
# Val C-Index: 0.7435179213921079
#
# [46/180] {'n_estimators': 115, 'max_depth': 3, 'min_samples_leaf': 1}
# Val C-Index: 0.7335806522357499
#
# [47/180] {'n_estimators': 115, 'max_depth': 3, 'min_samples_leaf': 2}
# Val C-Index: 0.7336523074050189
#
# [48/180] {'n_estimators': 115, 'max_depth': 3, 'min_samples_leaf': 3}
# Val C-Index: 0.733747847630711
#
# [49/180] {'n_estimators': 115, 'max_depth': 4, 'min_samples_leaf': 1}
# Val C-Index: 0.7404041785820528
#
# [50/180] {'n_estimators': 115, 'max_depth': 4, 'min_samples_leaf': 2}
# Val C-Index: 0.7406734283090032
#
# [51/180] {'n_estimators': 115, 'max_depth': 4, 'min_samples_leaf': 3}
# Val C-Index: 0.7403911503694584
#
# [52/180] {'n_estimators': 115, 'max_depth': 5, 'min_samples_leaf': 1}
# Val C-Index: 0.7450053089966322
#
# [53/180] {'n_estimators': 115, 'max_depth': 5, 'min_samples_leaf': 2}
# Val C-Index: 0.7446361763064583
#
# [54/180] {'n_estimators': 115, 'max_depth': 5, 'min_samples_leaf': 3}
# Val C-Index: 0.7431509600706998
#
# [55/180] {'n_estimators': 116, 'max_depth': 3, 'min_samples_leaf': 1}
# Val C-Index: 0.7337000775178649
#
# [56/180] {'n_estimators': 116, 'max_depth': 3, 'min_samples_leaf': 2}
# Val C-Index: 0.7337413335244137
#
# [57/180] {'n_estimators': 116, 'max_depth': 3, 'min_samples_leaf': 3}
# Val C-Index: 0.7337999604810884
#
# [58/180] {'n_estimators': 116, 'max_depth': 4, 'min_samples_leaf': 1}
# Val C-Index: 0.7404476059573674
#
# [59/180] {'n_estimators': 116, 'max_depth': 4, 'min_samples_leaf': 2}
# Val C-Index: 0.740714684315552
#
# [60/180] {'n_estimators': 116, 'max_depth': 4, 'min_samples_leaf': 3}
# Val C-Index: 0.7403520657316752
#
# [61/180] {'n_estimators': 116, 'max_depth': 5, 'min_samples_leaf': 1}
# Val C-Index: 0.7452354740857995
#
# [62/180] {'n_estimators': 116, 'max_depth': 5, 'min_samples_leaf': 2}
# Val C-Index: 0.7446188053563325
#
# [63/180] {'n_estimators': 116, 'max_depth': 5, 'min_samples_leaf': 3}
# Val C-Index: 0.7432291293462661
#
# [64/180] {'n_estimators': 117, 'max_depth': 3, 'min_samples_leaf': 1}
# Val C-Index: 0.7335980231858756
#
# [65/180] {'n_estimators': 117, 'max_depth': 3, 'min_samples_leaf': 2}
# Val C-Index: 0.7337196198367565
#
# [66/180] {'n_estimators': 117, 'max_depth': 3, 'min_samples_leaf': 3}
# Val C-Index: 0.7337521903682425
#
# [67/180] {'n_estimators': 117, 'max_depth': 4, 'min_samples_leaf': 1}
# Val C-Index: 0.7404410918510702
#
# [68/180] {'n_estimators': 117, 'max_depth': 4, 'min_samples_leaf': 2}
# Val C-Index: 0.7407429121095065
#
# [69/180] {'n_estimators': 117, 'max_depth': 4, 'min_samples_leaf': 3}
# Val C-Index: 0.7404041785820528
#
# [70/180] {'n_estimators': 117, 'max_depth': 5, 'min_samples_leaf': 1}
# Val C-Index: 0.7454460968560752
#
# [71/180] {'n_estimators': 117, 'max_depth': 5, 'min_samples_leaf': 2}
# Val C-Index: 0.7445840634560809
#
# [72/180] {'n_estimators': 117, 'max_depth': 5, 'min_samples_leaf': 3}
# Val C-Index: 0.7432399861900947
#
# [73/180] {'n_estimators': 118, 'max_depth': 3, 'min_samples_leaf': 1}
# Val C-Index: 0.7336479646674875
#
# [74/180] {'n_estimators': 118, 'max_depth': 3, 'min_samples_leaf': 2}
# Val C-Index: 0.7337196198367565
#
# [75/180] {'n_estimators': 118, 'max_depth': 3, 'min_samples_leaf': 3}
# Val C-Index: 0.7337521903682425
#
# [76/180] {'n_estimators': 118, 'max_depth': 4, 'min_samples_leaf': 1}
# Val C-Index: 0.7404758337513219
#
# [77/180] {'n_estimators': 118, 'max_depth': 4, 'min_samples_leaf': 2}
# Val C-Index: 0.7408514805477929
#
# [78/180] {'n_estimators': 118, 'max_depth': 4, 'min_samples_leaf': 3}
# Val C-Index: 0.7401479570676968
#
# [79/180] {'n_estimators': 118, 'max_depth': 5, 'min_samples_leaf': 1}
# Val C-Index: 0.745511237919047
#
# [80/180] {'n_estimators': 118, 'max_depth': 5, 'min_samples_leaf': 2}
# Val C-Index: 0.7445970916686752
# [81/180] {'n_estimators': 118, 'max_depth': 5, 'min_samples_leaf': 3}
# Val C-Index: 0.7432465002963918
#
# [82/180] {'n_estimators': 119, 'max_depth': 3, 'min_samples_leaf': 1}
# Val C-Index: 0.7337500189994767
#
# [83/180] {'n_estimators': 119, 'max_depth': 3, 'min_samples_leaf': 2}
# Val C-Index: 0.7338086459561514
#
# [84/180] {'n_estimators': 119, 'max_depth': 3, 'min_samples_leaf': 3}
# Val C-Index: 0.7338303596438087
#
# [85/180] {'n_estimators': 119, 'max_depth': 4, 'min_samples_leaf': 1}
# Val C-Index: 0.7405887449271398
#
# [86/180] {'n_estimators': 119, 'max_depth': 4, 'min_samples_leaf': 2}
# Val C-Index: 0.740834109597667
#
# [87/180] {'n_estimators': 119, 'max_depth': 4, 'min_samples_leaf': 3}
# Val C-Index: 0.7402652109810461
#
# [88/180] {'n_estimators': 119, 'max_depth': 5, 'min_samples_leaf': 1}
# Val C-Index: 0.7455850644570818
#
# [89/180] {'n_estimators': 119, 'max_depth': 5, 'min_samples_leaf': 2}
# Val C-Index: 0.7447252024258532
#
# [90/180] {'n_estimators': 119, 'max_depth': 5, 'min_samples_leaf': 3}
# Val C-Index: 0.7434006674787585
#
# [91/180] {'n_estimators': 120, 'max_depth': 3, 'min_samples_leaf': 1}
# Val C-Index: 0.7339421851352437
#
# [92/180] {'n_estimators': 120, 'max_depth': 3, 'min_samples_leaf': 2}
# Val C-Index: 0.733940013766478
#
# [93/180] {'n_estimators': 120, 'max_depth': 3, 'min_samples_leaf': 3}
# Val C-Index: 0.733931328291415
#
# [94/180] {'n_estimators': 120, 'max_depth': 4, 'min_samples_leaf': 1}
# Val C-Index: 0.7406625714651746
#
# [95/180] {'n_estimators': 120, 'max_depth': 4, 'min_samples_leaf': 2}
# Val C-Index: 0.740875365604216
#
# [96/180] {'n_estimators': 120, 'max_depth': 4, 'min_samples_leaf': 3}
# Val C-Index: 0.7403238379377208
#
# [97/180] {'n_estimators': 120, 'max_depth': 5, 'min_samples_leaf': 1}
# Val C-Index: 0.7454916956001555
#
# [98/180] {'n_estimators': 120, 'max_depth': 5, 'min_samples_leaf': 2}
# Val C-Index: 0.7445167510243432
#
# [99/180] {'n_estimators': 120, 'max_depth': 5, 'min_samples_leaf': 3}
# Val C-Index: 0.7433789537911013
#
# [100/180] {'n_estimators': 121, 'max_depth': 3, 'min_samples_leaf': 1}
# Val C-Index: 0.7338748727035062
#
# [101/180] {'n_estimators': 121, 'max_depth': 3, 'min_samples_leaf': 2}
# Val C-Index: 0.7338900722848662
#
# [102/180] {'n_estimators': 121, 'max_depth': 3, 'min_samples_leaf': 3}
# Val C-Index: 0.7337967034279399
#
# [103/180] {'n_estimators': 121, 'max_depth': 4, 'min_samples_leaf': 1}
# Val C-Index: 0.7409035933981704
#
# [104/180] {'n_estimators': 121, 'max_depth': 4, 'min_samples_leaf': 2}
# Val C-Index: 0.7410773028994287
#
# [105/180] {'n_estimators': 121, 'max_depth': 4, 'min_samples_leaf': 3}
# Val C-Index: 0.7405692026082482
#
# [106/180] {'n_estimators': 121, 'max_depth': 5, 'min_samples_leaf': 1}
# Val C-Index: 0.7451464479664046
#
# [107/180] {'n_estimators': 121, 'max_depth': 5, 'min_samples_leaf': 2}
# Val C-Index: 0.7442019025533125
#
# [108/180] {'n_estimators': 121, 'max_depth': 5, 'min_samples_leaf': 3}
# Val C-Index: 0.7430727907951336
#
# [109/180] {'n_estimators': 122, 'max_depth': 3, 'min_samples_leaf': 1}
# Val C-Index: 0.7340377253609358
#
# [110/180] {'n_estimators': 122, 'max_depth': 3, 'min_samples_leaf': 2}
# Val C-Index: 0.7341701788556453
#
# [111/180] {'n_estimators': 122, 'max_depth': 3, 'min_samples_leaf': 3}
# Val C-Index: 0.7340333826234043
#
# [112/180] {'n_estimators': 122, 'max_depth': 4, 'min_samples_leaf': 1}
# Val C-Index: 0.7411250730122747
#
# [113/180] {'n_estimators': 122, 'max_depth': 4, 'min_samples_leaf': 2}
# Val C-Index: 0.7413031252510646
#
# [114/180] {'n_estimators': 122, 'max_depth': 4, 'min_samples_leaf': 3}
# Val C-Index: 0.7406604000964088
#
# [115/180] {'n_estimators': 122, 'max_depth': 5, 'min_samples_leaf': 1}
# Val C-Index: 0.745111706066153
#
# [116/180] {'n_estimators': 122, 'max_depth': 5, 'min_samples_leaf': 2}
# Val C-Index: 0.7442409871910957
#
# [117/180] {'n_estimators': 122, 'max_depth': 5, 'min_samples_leaf': 3}
# Val C-Index: 0.7431878733397171
#
# [118/180] {'n_estimators': 123, 'max_depth': 3, 'min_samples_leaf': 1}
# Val C-Index: 0.7338596731221461
#
# [119/180] {'n_estimators': 123, 'max_depth': 3, 'min_samples_leaf': 2}
# Val C-Index: 0.7339508706103066
#
# [120/180] {'n_estimators': 123, 'max_depth': 3, 'min_samples_leaf': 3}
# Val C-Index: 0.7338249312218943
#
# [121/180] {'n_estimators': 123, 'max_depth': 4, 'min_samples_leaf': 1}
# Val C-Index: 0.7413660949452706
#
# [122/180] {'n_estimators': 123, 'max_depth': 4, 'min_samples_leaf': 2}
# Val C-Index: 0.7415680322404834
#
# [123/180] {'n_estimators': 123, 'max_depth': 4, 'min_samples_leaf': 3}
# Val C-Index: 0.740875365604216
#
# [124/180] {'n_estimators': 123, 'max_depth': 5, 'min_samples_leaf': 1}
# Val C-Index: 0.745207246291845
#
# [125/180] {'n_estimators': 123, 'max_depth': 5, 'min_samples_leaf': 2}
# Val C-Index: 0.7442431585598613
#
# [126/180] {'n_estimators': 123, 'max_depth': 5, 'min_samples_leaf': 3}
# Val C-Index: 0.7433485546283811
#
# [127/180] {'n_estimators': 124, 'max_depth': 3, 'min_samples_leaf': 1}
# Val C-Index: 0.734092009580079
#
# [128/180] {'n_estimators': 124, 'max_depth': 3, 'min_samples_leaf': 2}
# Val C-Index: 0.7341245801115649
#
# [129/180] {'n_estimators': 124, 'max_depth': 3, 'min_samples_leaf': 3}
# Val C-Index: 0.7340550963110616
#
# [130/180] {'n_estimators': 124, 'max_depth': 4, 'min_samples_leaf': 1}
# Val C-Index: 0.7414942057024486
#
# [131/180] {'n_estimators': 124, 'max_depth': 4, 'min_samples_leaf': 2}
# Val C-Index: 0.7416700865724727
#
# [132/180] {'n_estimators': 124, 'max_depth': 4, 'min_samples_leaf': 3}
# Val C-Index: 0.7410707887931315
#
# [133/180] {'n_estimators': 124, 'max_depth': 5, 'min_samples_leaf': 1}
# Val C-Index: 0.7448902264520486
#
# [134/180] {'n_estimators': 124, 'max_depth': 5, 'min_samples_leaf': 2}
# Val C-Index: 0.7440499067397115
#
# [135/180] {'n_estimators': 124, 'max_depth': 5, 'min_samples_leaf': 3}
# Val C-Index: 0.7432443289276262
#
# [136/180] {'n_estimators': 125, 'max_depth': 3, 'min_samples_leaf': 1}
# Val C-Index: 0.7338271025906601
#
# [137/180] {'n_estimators': 125, 'max_depth': 3, 'min_samples_leaf': 2}
# Val C-Index: 0.733803217534237
#
# [138/180] {'n_estimators': 125, 'max_depth': 3, 'min_samples_leaf': 3}
# Val C-Index: 0.7337489333150938
#
# [139/180] {'n_estimators': 125, 'max_depth': 4, 'min_samples_leaf': 1}
# Val C-Index: 0.7415246048651688
#
# [140/180] {'n_estimators': 125, 'max_depth': 4, 'min_samples_leaf': 2}
# Val C-Index: 0.7417808263795249
#
# [141/180] {'n_estimators': 125, 'max_depth': 4, 'min_samples_leaf': 3}
# Val C-Index: 0.741155472174995
#
# [142/180] {'n_estimators': 125, 'max_depth': 5, 'min_samples_leaf': 1}
# Val C-Index: 0.7446926318943673
#
# [143/180] {'n_estimators': 125, 'max_depth': 5, 'min_samples_leaf': 2}
# Val C-Index: 0.7440390498958829
#
# [144/180] {'n_estimators': 125, 'max_depth': 5, 'min_samples_leaf': 3}
# Val C-Index: 0.7430684480576021
#
# [145/180] {'n_estimators': 126, 'max_depth': 3, 'min_samples_leaf': 1}
# Val C-Index: 0.733963898822901
#
# [146/180] {'n_estimators': 126, 'max_depth': 3, 'min_samples_leaf': 2}
# Val C-Index: 0.7339009291286949
#
# [147/180] {'n_estimators': 126, 'max_depth': 3, 'min_samples_leaf': 3}
# Val C-Index: 0.7338423021720202
#
# [148/180] {'n_estimators': 126, 'max_depth': 4, 'min_samples_leaf': 1}
# Val C-Index: 0.7417417417417418
#
# [149/180] {'n_estimators': 126, 'max_depth': 4, 'min_samples_leaf': 2}
# Val C-Index: 0.7418763666052169
#
# [150/180] {'n_estimators': 126, 'max_depth': 4, 'min_samples_leaf': 3}
# Val C-Index: 0.7413204962011903
#
# [151/180] {'n_estimators': 126, 'max_depth': 5, 'min_samples_leaf': 1}
# Val C-Index: 0.7448858837145171
#
# [152/180] {'n_estimators': 126, 'max_depth': 5, 'min_samples_leaf': 2}
# Val C-Index: 0.7440868200087289
#
# [153/180] {'n_estimators': 126, 'max_depth': 5, 'min_samples_leaf': 3}
# Val C-Index: 0.743437580747776
#
# [154/180] {'n_estimators': 127, 'max_depth': 3, 'min_samples_leaf': 1}
# Val C-Index: 0.7339682415604325
#
# [155/180] {'n_estimators': 127, 'max_depth': 3, 'min_samples_leaf': 2}
# Val C-Index: 0.7339009291286949
#
# [156/180] {'n_estimators': 127, 'max_depth': 3, 'min_samples_leaf': 3}
# Val C-Index: 0.7338813868098033
#
# [157/180] {'n_estimators': 127, 'max_depth': 4, 'min_samples_leaf': 1}
# Val C-Index: 0.7415636895029519
#
# [158/180] {'n_estimators': 127, 'max_depth': 4, 'min_samples_leaf': 2}
# Val C-Index: 0.7416809434163013
#
# [159/180] {'n_estimators': 127, 'max_depth': 4, 'min_samples_leaf': 3}
# Val C-Index: 0.7411511294374635
#
# [160/180] {'n_estimators': 127, 'max_depth': 5, 'min_samples_leaf': 1}
# Val C-Index: 0.7447230310570875
# [161/180] {'n_estimators': 127, 'max_depth': 5, 'min_samples_leaf': 2}
# Val C-Index: 0.7438436267069672
#
# [162/180] {'n_estimators': 127, 'max_depth': 5, 'min_samples_leaf': 3}
# Val C-Index: 0.7433854678973985
#
# [163/180] {'n_estimators': 128, 'max_depth': 3, 'min_samples_leaf': 1}
# Val C-Index: 0.7338987577599291
#
# [164/180] {'n_estimators': 128, 'max_depth': 3, 'min_samples_leaf': 2}
# Val C-Index: 0.7339552133478381
#
# [165/180] {'n_estimators': 128, 'max_depth': 3, 'min_samples_leaf': 3}
# Val C-Index: 0.7338488162783173
#
# [166/180] {'n_estimators': 128, 'max_depth': 4, 'min_samples_leaf': 1}
# Val C-Index: 0.7416158023533295
#
# [167/180] {'n_estimators': 128, 'max_depth': 4, 'min_samples_leaf': 2}
# Val C-Index: 0.7417851691170563
#
# [168/180] {'n_estimators': 128, 'max_depth': 4, 'min_samples_leaf': 3}
# Val C-Index: 0.7411511294374635
#
# [169/180] {'n_estimators': 128, 'max_depth': 5, 'min_samples_leaf': 1}
# Val C-Index: 0.7446730895754757
#
# [170/180] {'n_estimators': 128, 'max_depth': 5, 'min_samples_leaf': 2}
# Val C-Index: 0.7437589433251038
#
# [171/180] {'n_estimators': 128, 'max_depth': 5, 'min_samples_leaf': 3}
# Val C-Index: 0.7431922160772486
#
# [172/180] {'n_estimators': 129, 'max_depth': 3, 'min_samples_leaf': 1}
# Val C-Index: 0.7338119030093
#
# [173/180] {'n_estimators': 129, 'max_depth': 3, 'min_samples_leaf': 2}
# Val C-Index: 0.7338683585972089
#
# [174/180] {'n_estimators': 129, 'max_depth': 3, 'min_samples_leaf': 3}
# Val C-Index: 0.7338336166969572
#
# [175/180] {'n_estimators': 129, 'max_depth': 4, 'min_samples_leaf': 1}
# Val C-Index: 0.7416614010974097
#
# [176/180] {'n_estimators': 129, 'max_depth': 4, 'min_samples_leaf': 2}
# Val C-Index: 0.7418285964923709
#
# [177/180] {'n_estimators': 129, 'max_depth': 4, 'min_samples_leaf': 3}
# Val C-Index: 0.7411576435437607
#
# [178/180] {'n_estimators': 129, 'max_depth': 5, 'min_samples_leaf': 1}
# Val C-Index: 0.7446600613628813
#
# [179/180] {'n_estimators': 129, 'max_depth': 5, 'min_samples_leaf': 2}
# Val C-Index: 0.7436199757240972
#
# [180/180] {'n_estimators': 129, 'max_depth': 5, 'min_samples_leaf': 3}
# Val C-Index: 0.743276899459112
#
# Performance for best hyperparameters:
# - Train C-Index: 0.8142
# - Val C-Index: 0.7456
# - Test C-Index: 0.7796

# %% [markdown]
# #### Expected Output
# Note, your actual output will vary depending on the hyper-parameters that you chose and the mask that you chose.
# ```Python
# Performance for best hyperparameters:
# - Train C-Index: 0.8131
# - Val C-Index: 0.7454
# - Test C-Index: 0.7797
# ```

# %% [markdown]
# <a name='10'></a>
# ## 10. Comparison
#
# For good measure, retest on the subgroup from before to see if your new models do better.

# %%
performance, subgroup_size = bad_subset(best_rf, X_test, y_test)
print(f"C-Index (no imputation): {performance}")

performance, subgroup_size = bad_subset(rf_mean_imputed, X_test, y_test)
print(f"C-Index (mean imputation): {performance}")

performance, subgroup_size = bad_subset(rf_imputed, X_test, y_test)
print(f"C-Index (multivariate feature imputation): {performance}")
# Out:
# C-Index (no imputation): 0.6663914120561519
# C-Index (mean imputation): 0.6746097282843774
# C-Index (multivariate feature imputation): 0.6804293971924029

# %% [markdown]
# We should see that avoiding complete case analysis (i.e. analysis only on observations for which there is no missing data) allows our model to generalize a bit better. Remember to examine your missing cases to judge whether they are missing at random or not!

# %% [markdown]
# <a name='11'></a>
# ## 11. Explanations: SHAP
#
# Using a random forest has improved results, but we've lost some of the natural interpretability of trees. In this section we'll try to explain the predictions using slightly more sophisticated techniques.
#
# You choose to apply **SHAP (SHapley Additive exPlanations) **, a cutting edge method that explains predictions made by black-box machine learning models (i.e. models which are too complex to be understandable by humans as is).
#
# > Given a prediction made by a machine learning model, SHAP values explain the prediction by quantifying the additive importance of each feature to the prediction. SHAP values have their roots in cooperative game theory, where Shapley values are used to quantify the contribution of each player to the game.
# >
# > Although it is computationally expensive to compute SHAP values for general black-box models, in the case of trees and forests there exists a fast polynomial-time algorithm. For more details, see the [TreeShap paper](https://arxiv.org/pdf/1802.03888.pdf).
#
# We'll use the [shap library](https://github.com/slundberg/shap) to do this for our random forest model. Run the next cell to output the most at risk individuals in the test set according to our model.

# %%
X_test_risk = X_test.copy(deep=True)
X_test_risk.loc[:, 'risk'] = rf_imputed.predict_proba(X_test_risk)[:, 1]
X_test_risk = X_test_risk.sort_values(by='risk', ascending=False)
X_test_risk.head()
# Out:
#        Age  Diastolic BP  Poverty index  Race  Red blood cells  \
# 5493  67.0          80.0           30.0   1.0             77.7
# 2608  71.0          80.0          104.0   1.0             43.8
# 6337  69.0          80.0          233.0   1.0             77.7
# 2050  66.0         100.0           69.0   2.0             42.9
# 6609  72.0          90.0           75.0   1.0             29.3
#
#       Sedimentation rate  Serum Albumin  Serum Cholesterol  Serum Iron  \
# 5493                59.0            3.4              231.0        36.0
# 2608                23.0            4.0              201.0       119.0
# 6337                48.0            4.2              159.0        87.0
# 2050                47.0            3.8              233.0       170.0
# 6609                59.0            3.9              216.0        64.0
#
#       Serum Magnesium  Serum Protein  Sex  Systolic BP   TIBC    TS  \
# 5493             1.40            6.3  1.0        170.0  202.0  17.8
# 2608             1.60            7.0  1.0        166.0  311.0  38.3
# 6337             1.81            6.9  1.0        146.0  291.0  29.9
# 2050             1.42            8.6  1.0        180.0  411.0  41.4
# 6609             1.63            7.4  2.0        182.0  322.0  19.9
#
#       White blood cells        BMI  Pulse pressure      risk
# 5493                8.4  17.029470            90.0  0.623329
# 2608                6.3  17.760766            86.0  0.558428
# 6337               15.2  17.931276            66.0  0.531703
# 2050                7.2  22.129498            80.0  0.522450
# 6609                9.3  22.281793            92.0  0.522198

# %% [markdown]
# We can use SHAP values to try and understand the model output on specific individuals using force plots. Run the cell below to see a force plot on the riskiest individual.

# %%
explainer = shap.TreeExplainer(rf_imputed)
i = 0
shap_value = explainer.shap_values(X_test.loc[X_test_risk.index[i], :])[1]
shap.force_plot(explainer.expected_value[1], shap_value, feature_names=X_test.columns, matplotlib=True)

# %% [markdown]
# How to read this chart:
# - The red sections on the left are features which push the model towards the final prediction in the positive direction (i.e. a higher Age increases the predicted risk).
# - The blue sections on the right are features that push the model towards the final prediction in the negative direction (if an increase in a feature leads to a lower risk, it will be shown in blue).
# - Note that the exact output of your chart will differ depending on the hyper-parameters that you choose for your model.
#
# We can also use SHAP values to understand the model output in aggregate. Run the next cell to initialize the SHAP values (this may take a few minutes).

# %%
shap_values = shap.TreeExplainer(rf_imputed).shap_values(X_test)[1]

# %% [markdown]
# Run the next cell to see a summary plot of the SHAP values for each feature on each of the test examples. The colors indicate the value of the feature.

# %%
shap.summary_plot(shap_values, X_test)

# %% [markdown]
# Clearly we see that being a woman (`sex = 2.0`, as opposed to men for which `sex = 1.0`) has a negative SHAP value, meaning that it reduces the risk of dying within 10 years. High age and high systolic blood pressure have positive SHAP values, and are therefore related to increased mortality.
#
# You can see how features interact using dependence plots. These plot the SHAP value for a given feature for each data point, and color the points in using the value for another feature. This lets us begin to explain the variation in SHAP value for a single value of the main feature.
#
# Run the next cell to see the interaction between Age and Sex.

# %%
shap.dependence_plot('Age', shap_values, X_test, interaction_index='Sex')

# %% [markdown]
# We see that while Age > 50 is generally bad (positive SHAP value), being a woman generally reduces the impact of age. This makes sense since we know that women generally live longer than men.
#
# Let's now look at poverty index and age.

# %%
shap.dependence_plot('Poverty index', shap_values, X_test, interaction_index='Age')

# %% [markdown]
# We see that the impact of poverty index drops off quickly, and for higher income individuals age begins to explain much of variation in the impact of poverty index.
#
# Try some other pairs and see what other interesting relationships you can find!

# %% [markdown]
# # Congratulations!
#
# You have completed the second assignment in Course 2. Along the way you've learned to fit decision trees, random forests, and deal with missing data. Now you're ready to move on to week 3!
